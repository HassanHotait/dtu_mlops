# %% [markdown]
# # Inference and Validation
#
# Now that you have a trained network, you can use it for making predictions. This is typically called **inference**, a term borrowed from statistics. However, neural networks have a tendency to perform *too well* on the training data and aren't able to generalize to data that hasn't been seen before. This is called **overfitting** and it impairs inference performance. To test for overfitting while training, we measure the performance on data not in the training set called the **validation** set. We avoid overfitting through regularization such as dropout while monitoring the validation performance during training. In this notebook, I'll show you how to do this in PyTorch.
#
# As usual, let's start by loading the dataset through torchvision. You'll learn more about torchvision and loading data in a later part. This time we'll be taking advantage of the test set which you can get by setting `train=False` here:
#
# ```python
# testset = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', download=True, train=False, transform=transform)
# ```
#
# The test set contains images just like the training set. Typically you'll see 10-20% of the original dataset held out for testing and validation with the rest being used for training.

# %%
import torch
from torchvision import datasets, transforms

# Define a transform to normalize the data
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5,), (0.5,))])
# Download and load the training data
trainset = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', download=True, train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

# Download and load the test data
testset = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', download=True, train=False, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=True)

# %% [markdown]
# Here I'll create a model like normal, using the same one from my solution for part 4.

# %%
from torch import nn, optim
import torch.nn.functional as F

class Classifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 10)
        
    def forward(self, x):
        # make sure input tensor is flattened
        x = x.view(x.shape[0], -1)
        
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.log_softmax(self.fc4(x), dim=1)
        
        return x

# %% [markdown]
# The goal of validation is to measure the model's performance on data that isn't part of the training set. Performance here is up to the developer to define though. Typically this is just accuracy, the percentage of classes the network predicted correctly. Other options are [precision and recall](https://en.wikipedia.org/wiki/Precision_and_recall#Definition_(classification_context)) and top-5 error rate. We'll focus on accuracy here. First I'll do a forward pass with one batch from the test set.

# %%
model = Classifier()

images, labels = next(iter(testloader))
# Get the class probabilities
ps = torch.exp(model(images))
# Make sure the shape is appropriate, we should get 10 class probabilities for 64 examples
print(ps.shape)
# Out:
# torch.Size([64, 10])

# %% [markdown]
# With the probabilities, we can get the most likely class using the `ps.topk` method. This returns the $k$ highest values. Since we just want the most likely class, we can use `ps.topk(1)`. This returns a tuple of the top-$k$ values and the top-$k$ indices. If the highest value is the fifth element, we'll get back 4 as the index.

# %%
top_p, top_class = ps.topk(1, dim=1)
# Look at the most likely classes for the first 10 examples
print(top_class[:10,:])
# Out:
# tensor([[8],
#         [8],
#         [8],
#         [8],
#         [8],
#         [8],
#         [8],
#         [5],
#         [8],
#         [8]])

# %% [markdown]
# Now we can check if the predicted classes match the labels. This is simple to do by equating `top_class` and `labels`, but we have to be careful of the shapes. Here `top_class` is a 2D tensor with shape `(64, 1)` while `labels` is 1D with shape `(64)`. To get the equality to work out the way we want, `top_class` and `labels` must have the same shape.
#
# If we do
#
# ```python
# equals = top_class == labels
# ```
#
# `equals` will have shape `(64, 64)`, try it yourself. What it's doing is comparing the one element in each row of `top_class` with each element in `labels` which returns 64 True/False boolean values for each row.

# %%
equals = top_class == labels.view(*top_class.shape)

# %% [markdown]
# Now we need to calculate the percentage of correct predictions. `equals` has binary values, either 0 or 1. This means that if we just sum up all the values and divide by the number of values, we get the percentage of correct predictions. This is the same operation as taking the mean, so we can get the accuracy with a call to `torch.mean`. If only it was that simple. If you try `torch.mean(equals)`, you'll get an error
#
# ```
# RuntimeError: mean is not implemented for type torch.ByteTensor
# ```
#
# This happens because `equals` has type `torch.ByteTensor` but `torch.mean` isn't implemented for tensors with that type. So we'll need to convert `equals` to a float tensor. Note that when we take `torch.mean` it returns a scalar tensor, to get the actual value as a float we'll need to do `accuracy.item()`.

# %%
accuracy = torch.mean(equals.type(torch.FloatTensor))
print(f'Accuracy: {accuracy.item()*100}%')
# Out:
# Accuracy: 9.375%

# %% [markdown]
# The network is untrained so it's making random guesses and we should see an accuracy around 10%. Now let's train our network and include our validation pass so we can measure how well the network is performing on the test set. Since we're not updating our parameters in the validation pass, we can speed up our code by turning off gradients using `torch.no_grad()`:
#
# ```python
# # turn off gradients
# with torch.no_grad():
#     # validation pass here
#     for images, labels in testloader:
#         ...
# ```
#
# >**Exercise:** Implement the validation loop below and print out the total accuracy after the loop. You can largely copy and paste the code from above, but I suggest typing it in because writing it out yourself is essential for building the skill. In general you'll always learn more by typing it rather than copy-pasting. You should be able to get an accuracy above 80%.

# %%
model = Classifier()
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

epochs = 5
steps = 0

train_losses, test_losses = [], []
for e in range(epochs):
    running_loss = 0
    for images, labels in trainloader:
        
        optimizer.zero_grad()
        
        log_ps = model(images)
        loss = criterion(log_ps, labels)
        print(loss.item())
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()

        # Get Training Accuracy
        ps = torch.exp(log_ps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy = torch.mean(equals.type(torch.FloatTensor))
        print("Batch Training Accuracy: ",accuracy)
        
        
    else:
        ## TODO: Implement the validation pass and print out the validation accuracy
        pass
# Out:
# 2.309842586517334
# Batch Training Accuracy:  tensor(0.0625)
# 2.243100643157959
# Batch Training Accuracy:  tensor(0.1562)
# 2.116377592086792
# Batch Training Accuracy:  tensor(0.1719)
# 1.9028573036193848
# Batch Training Accuracy:  tensor(0.3438)
# 1.7577754259109497
# Batch Training Accuracy:  tensor(0.3281)
# 1.541589379310608
# Batch Training Accuracy:  tensor(0.3438)
# 1.4692434072494507
# Batch Training Accuracy:  tensor(0.3906)
# 1.1882050037384033
# Batch Training Accuracy:  tensor(0.4688)
# 1.1205211877822876
# Batch Training Accuracy:  tensor(0.5781)
# 1.1994755268096924
# Batch Training Accuracy:  tensor(0.5312)
# 1.1475694179534912
# Batch Training Accuracy:  tensor(0.4844)
# 1.0543245077133179
# Batch Training Accuracy:  tensor(0.5469)
# 0.8532638549804688
# Batch Training Accuracy:  tensor(0.6406)
# 1.1922221183776855
# Batch Training Accuracy:  tensor(0.5312)
# 0.9844264388084412
# Batch Training Accuracy:  tensor(0.5312)
# 1.2756898403167725
# Batch Training Accuracy:  tensor(0.4375)
# 1.0758421421051025
# Batch Training Accuracy:  tensor(0.5938)
# 1.071001410484314
# Batch Training Accuracy:  tensor(0.5938)
# 1.0049703121185303
# Batch Training Accuracy:  tensor(0.6250)
# 0.7935482859611511
# Batch Training Accuracy:  tensor(0.7344)
# 0.8547773361206055
# Batch Training Accuracy:  tensor(0.7500)
# 1.2709633111953735
# Batch Training Accuracy:  tensor(0.5781)
# 1.1478626728057861
# Batch Training Accuracy:  tensor(0.5156)
# 0.8148683905601501
# Batch Training Accuracy:  tensor(0.6406)
# 0.953952431678772
# Batch Training Accuracy:  tensor(0.6406)
# 0.8943124413490295
# Batch Training Accuracy:  tensor(0.6875)
# 0.891627848148346
# Batch Training Accuracy:  tensor(0.6719)
# 0.8924475908279419
# Batch Training Accuracy:  tensor(0.6406)
# 0.7879236340522766
# Batch Training Accuracy:  tensor(0.7031)
# 0.780097246170044
# Batch Training Accuracy:  tensor(0.7031)
# 0.98822021484375
# Batch Training Accuracy:  tensor(0.6094)
# 0.7893784642219543
# Batch Training Accuracy:  tensor(0.7188)
# 0.8199942111968994
# Batch Training Accuracy:  tensor(0.6719)
# 0.7860482931137085
# Batch Training Accuracy:  tensor(0.6562)
# 0.8713815808296204
# Batch Training Accuracy:  tensor(0.6406)
# 0.9656388759613037
# Batch Training Accuracy:  tensor(0.6094)
# 0.8792063593864441
# Batch Training Accuracy:  tensor(0.7344)
# 0.8406801223754883
# Batch Training Accuracy:  tensor(0.6562)
# 0.8230205774307251
# Batch Training Accuracy:  tensor(0.6562)
# 0.7747617959976196
# Batch Training Accuracy:  tensor(0.7031)
# 0.8351687788963318
# Batch Training Accuracy:  tensor(0.6719)
# 0.8661697506904602
# Batch Training Accuracy:  tensor(0.7188)
# 0.853742241859436
# Batch Training Accuracy:  tensor(0.6875)
# 0.6249387860298157
# Batch Training Accuracy:  tensor(0.8281)
# 0.9860443472862244
# Batch Training Accuracy:  tensor(0.5625)
# 0.6783723831176758
# Batch Training Accuracy:  tensor(0.7344)
# 0.6805821061134338
# Batch Training Accuracy:  tensor(0.7969)
# 0.6518644094467163
# Batch Training Accuracy:  tensor(0.7812)
# 0.6128430366516113
# Batch Training Accuracy:  tensor(0.7656)
# 0.7734023332595825
# Batch Training Accuracy:  tensor(0.6406)
# 0.510190486907959
# Batch Training Accuracy:  tensor(0.7969)
# 0.7301660180091858
# Batch Training Accuracy:  tensor(0.7656)
# 0.825147807598114
# Batch Training Accuracy:  tensor(0.6875)
# 0.6750925183296204
# Batch Training Accuracy:  tensor(0.7500)
# 0.5254007577896118
# Batch Training Accuracy:  tensor(0.7969)
# 0.7040559649467468
# Batch Training Accuracy:  tensor(0.7031)
# 0.833184003829956
# Batch Training Accuracy:  tensor(0.7031)
# 0.6212282776832581
# Batch Training Accuracy:  tensor(0.7188)
# 0.6887176632881165
# Batch Training Accuracy:  tensor(0.7969)
# 0.8300251364707947
# Batch Training Accuracy:  tensor(0.7188)
# 0.4851585626602173
# Batch Training Accuracy:  tensor(0.7812)
# 0.6711697578430176
# Batch Training Accuracy:  tensor(0.7188)
# 0.7539744973182678
# Batch Training Accuracy:  tensor(0.7344)
# 0.796410322189331
# Batch Training Accuracy:  tensor(0.7344)
# 0.7326934933662415
# Batch Training Accuracy:  tensor(0.8125)
# 0.8529741168022156
# Batch Training Accuracy:  tensor(0.7031)
# 0.6754576563835144
# Batch Training Accuracy:  tensor(0.7031)
# 0.6166137456893921
# Batch Training Accuracy:  tensor(0.7344)
# 0.6684194803237915
# Batch Training Accuracy:  tensor(0.7344)
# 0.7630051374435425
# Batch Training Accuracy:  tensor(0.6719)
# 0.8021309971809387
# Batch Training Accuracy:  tensor(0.7344)
# 0.5903728604316711
# Batch Training Accuracy:  tensor(0.7969)
# 0.46748659014701843
# Batch Training Accuracy:  tensor(0.8281)
# 0.5916234850883484
# Batch Training Accuracy:  tensor(0.8125)
# 0.571441650390625
# Batch Training Accuracy:  tensor(0.7656)
# 0.7053996920585632
# Batch Training Accuracy:  tensor(0.7812)
# 0.7824146747589111
# Batch Training Accuracy:  tensor(0.7188)
# 0.5473504066467285
# Batch Training Accuracy:  tensor(0.8125)
# 0.5938971638679504
# Batch Training Accuracy:  tensor(0.7969)
# 0.5081366300582886
# Batch Training Accuracy:  tensor(0.7969)
# 0.5825849175453186
# Batch Training Accuracy:  tensor(0.7656)
# 0.45299094915390015
# Batch Training Accuracy:  tensor(0.8281)
# 0.6837154030799866
# Batch Training Accuracy:  tensor(0.7344)
# 0.5393818020820618
# Batch Training Accuracy:  tensor(0.8281)
# 0.46849626302719116
# Batch Training Accuracy:  tensor(0.8281)
# 0.4842316508293152
# Batch Training Accuracy:  tensor(0.8438)
# 0.6368904709815979
# Batch Training Accuracy:  tensor(0.7500)
# 0.7330327033996582
# Batch Training Accuracy:  tensor(0.7500)
# 0.7969598770141602
# Batch Training Accuracy:  tensor(0.7031)
# 0.5361626148223877
# Batch Training Accuracy:  tensor(0.7344)
# 0.5893754959106445
# Batch Training Accuracy:  tensor(0.7344)
# 0.6290289163589478
# Batch Training Accuracy:  tensor(0.7344)
# 0.675452709197998
# Batch Training Accuracy:  tensor(0.7500)
# 0.36339786648750305
# Batch Training Accuracy:  tensor(0.8281)
# 0.4844774901866913
# Batch Training Accuracy:  tensor(0.8594)
# 0.6970730423927307
# Batch Training Accuracy:  tensor(0.7500)
# 0.4707145094871521
# Batch Training Accuracy:  tensor(0.8594)
# 0.5987616777420044
# Batch Training Accuracy:  tensor(0.7969)
# 0.6541184782981873
# Batch Training Accuracy:  tensor(0.7656)
# 0.580586314201355
# Batch Training Accuracy:  tensor(0.8125)
# 0.5899919867515564
# Batch Training Accuracy:  tensor(0.7812)
# 0.7426878213882446
# Batch Training Accuracy:  tensor(0.7812)
# 0.6197618246078491
# Batch Training Accuracy:  tensor(0.7656)
# 0.5652182102203369
# Batch Training Accuracy:  tensor(0.7969)
# 0.4491797983646393
# Batch Training Accuracy:  tensor(0.8281)
# 0.3900006413459778
# Batch Training Accuracy:  tensor(0.8438)
# 0.8132774233818054
# Batch Training Accuracy:  tensor(0.6875)
# 0.6589515209197998
# Batch Training Accuracy:  tensor(0.7344)
# 0.6030061841011047
# Batch Training Accuracy:  tensor(0.8281)
# 0.5822725296020508
# Batch Training Accuracy:  tensor(0.7969)
# 0.4933089315891266
# Batch Training Accuracy:  tensor(0.7969)
# 0.7061492800712585
# Batch Training Accuracy:  tensor(0.7812)
# 0.5340995192527771
# Batch Training Accuracy:  tensor(0.7969)
# 0.49838677048683167
# Batch Training Accuracy:  tensor(0.7812)
# 0.4718695282936096
# Batch Training Accuracy:  tensor(0.8281)
# 0.5892165303230286
# Batch Training Accuracy:  tensor(0.7812)
# 0.5585322976112366
# Batch Training Accuracy:  tensor(0.7656)
# 0.5958865284919739
# Batch Training Accuracy:  tensor(0.8125)
# 0.6411358714103699
# Batch Training Accuracy:  tensor(0.7969)
# 0.5380080938339233
# Batch Training Accuracy:  tensor(0.7969)
# 0.7403073906898499
# Batch Training Accuracy:  tensor(0.7500)
# 0.44240179657936096
# Batch Training Accuracy:  tensor(0.8594)
# 0.4401925504207611
# Batch Training Accuracy:  tensor(0.8438)
# 0.5589557886123657
# Batch Training Accuracy:  tensor(0.7812)
# 0.5731695890426636
# Batch Training Accuracy:  tensor(0.8125)
# 0.7007597088813782
# Batch Training Accuracy:  tensor(0.6875)
# 0.5699401497840881
# Batch Training Accuracy:  tensor(0.7812)
# 0.39438164234161377
# Batch Training Accuracy:  tensor(0.8594)
# 0.5908044576644897
# Batch Training Accuracy:  tensor(0.7969)
# 0.9130698442459106
# Batch Training Accuracy:  tensor(0.7188)
# 0.685616672039032
# Batch Training Accuracy:  tensor(0.7656)
# 0.45586341619491577
# Batch Training Accuracy:  tensor(0.8281)
# 0.6659470796585083
# Batch Training Accuracy:  tensor(0.7188)
# 0.6872671842575073
# Batch Training Accuracy:  tensor(0.6875)
# 0.5602219104766846
# Batch Training Accuracy:  tensor(0.8125)
# 0.8073720335960388
# Batch Training Accuracy:  tensor(0.7344)
# 0.6877691149711609
# Batch Training Accuracy:  tensor(0.7344)
# 0.6314815878868103
# Batch Training Accuracy:  tensor(0.7969)
# 0.4964311420917511
# Batch Training Accuracy:  tensor(0.8750)
# 0.7602584958076477
# Batch Training Accuracy:  tensor(0.7188)
# 0.5407318472862244
# Batch Training Accuracy:  tensor(0.8125)
# 0.5643244981765747
# Batch Training Accuracy:  tensor(0.8281)
# 0.47768634557724
# Batch Training Accuracy:  tensor(0.8281)
# 0.7264636754989624
# Batch Training Accuracy:  tensor(0.7500)
# 0.5643426775932312
# Batch Training Accuracy:  tensor(0.8125)
# 0.9083454608917236
# Batch Training Accuracy:  tensor(0.7188)
# 0.6309391260147095
# Batch Training Accuracy:  tensor(0.7656)
# 0.551469087600708
# Batch Training Accuracy:  tensor(0.8438)
# 0.6458802819252014
# Batch Training Accuracy:  tensor(0.8281)
# 0.7425885200500488
# Batch Training Accuracy:  tensor(0.7031)
# 0.5202479362487793
# Batch Training Accuracy:  tensor(0.7656)
# 0.5547794103622437
# Batch Training Accuracy:  tensor(0.7969)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\hotai\OneDrive\Desktop\dtu_mlops\s1_development_environment\exercise_files\5_Inference_and_Validation.ipynb Cell 14 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/hotai/OneDrive/Desktop/dtu_mlops/s1_development_environment/exercise_files/5_Inference_and_Validation.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a> for e in range(epochs):
#      <a href='vscode-notebook-cell:/c%3A/Users/hotai/OneDrive/Desktop/dtu_mlops/s1_development_environment/exercise_files/5_Inference_and_Validation.ipynb#X16sZmlsZQ%3D%3D?line=9'>10</a>     running_loss = 0
# ---> <a href='vscode-notebook-cell:/c%3A/Users/hotai/OneDrive/Desktop/dtu_mlops/s1_development_environment/exercise_files/5_Inference_and_Validation.ipynb#X16sZmlsZQ%3D%3D?line=10'>11</a>     for images, labels in trainloader:
#      <a href='vscode-notebook-cell:/c%3A/Users/hotai/OneDrive/Desktop/dtu_mlops/s1_development_environment/exercise_files/5_Inference_and_Validation.ipynb#X16sZmlsZQ%3D%3D?line=12'>13</a>         optimizer.zero_grad()
#      <a href='vscode-notebook-cell:/c%3A/Users/hotai/OneDrive/Desktop/dtu_mlops/s1_development_environment/exercise_files/5_Inference_and_Validation.ipynb#X16sZmlsZQ%3D%3D?line=14'>15</a>         log_ps = model(images)
#
# File c:\Users\hotai\miniconda3\envs\dtu_mlops\Lib\site-packages\torch\utils\data\dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\hotai\miniconda3\envs\dtu_mlops\Lib\site-packages\torch\utils\data\dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     672 def _next_data(self):
#     673     index = self._next_index()  # may raise StopIteration
# --> 674     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675     if self._pin_memory:
#     676         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\hotai\miniconda3\envs\dtu_mlops\Lib\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File c:\Users\hotai\miniconda3\envs\dtu_mlops\Lib\site-packages\torch\utils\data\_utils\fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File c:\Users\hotai\miniconda3\envs\dtu_mlops\Lib\site-packages\torchvision\datasets\mnist.py:145, in MNIST.__getitem__(self, index)
#     142 img = Image.fromarray(img.numpy(), mode="L")
#     144 if self.transform is not None:
# --> 145     img = self.transform(img)
#     147 if self.target_transform is not None:
#     148     target = self.target_transform(target)
#
# File c:\Users\hotai\miniconda3\envs\dtu_mlops\Lib\site-packages\torchvision\transforms\transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File c:\Users\hotai\miniconda3\envs\dtu_mlops\Lib\site-packages\torchvision\transforms\transforms.py:137, in ToTensor.__call__(self, pic)
#     129 def __call__(self, pic):
#     130     """
#     131     Args:
#     132         pic (PIL Image or numpy.ndarray): Image to be converted to tensor.
#    (...)
#     135         Tensor: Converted image.
#     136     """
# --> 137     return F.to_tensor(pic)
#
# File c:\Users\hotai\miniconda3\envs\dtu_mlops\Lib\site-packages\torchvision\transforms\functional.py:172, in to_tensor(pic)
#     170 img = img.view(pic.size[1], pic.size[0], F_pil.get_image_num_channels(pic))
#     171 # put it from HWC to CHW format
# --> 172 img = img.permute((2, 0, 1)).contiguous()
#     173 if isinstance(img, torch.ByteTensor):
#     174     return img.to(dtype=default_float_dtype).div(255)
#
# KeyboardInterrupt:

# %%
# GPT Experimentation
model = Classifier()
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

epochs = 20
steps = 0

train_losses, test_losses = [], []
for e in range(epochs):
    running_loss = 0
    for images, labels in trainloader:
        
        optimizer.zero_grad()
        
        log_ps = model(images)
        loss = criterion(log_ps, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
    else:
        # Validation pass
        test_loss = 0
        accuracy = 0

        # Set the model to evaluation mode
        model.eval()

        with torch.no_grad():
            for images, labels in testloader:
                log_ps = model(images)
                test_loss += criterion(log_ps, labels).item()

                ps = torch.exp(log_ps)
                top_p, top_class = ps.topk(1, dim=1)
                equals = top_class == labels.view(*top_class.shape)
                accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

        # Set the model back to training mode
        model.train()

        train_losses.append(running_loss/len(trainloader))
        test_losses.append(test_loss/len(testloader))

        print("Epoch: {}/{}.. ".format(e+1, epochs),
              "Training Loss: {:.3f}.. ".format(running_loss/len(trainloader)),
              "Validation Loss: {:.3f}.. ".format(test_loss/len(testloader)),
              "Validation Accuracy: {:.3f}".format(accuracy/len(testloader)))
# Out:
# Epoch: 1/20..  Training Loss: 0.522..  Validation Loss: 0.441..  Validation Accuracy: 0.844
# Epoch: 2/20..  Training Loss: 0.394..  Validation Loss: 0.425..  Validation Accuracy: 0.849
# Epoch: 3/20..  Training Loss: 0.354..  Validation Loss: 0.410..  Validation Accuracy: 0.859
# Epoch: 4/20..  Training Loss: 0.337..  Validation Loss: 0.374..  Validation Accuracy: 0.864
# Epoch: 5/20..  Training Loss: 0.320..  Validation Loss: 0.372..  Validation Accuracy: 0.868
# Epoch: 6/20..  Training Loss: 0.302..  Validation Loss: 0.404..  Validation Accuracy: 0.860
# Epoch: 7/20..  Training Loss: 0.296..  Validation Loss: 0.378..  Validation Accuracy: 0.871
# Epoch: 8/20..  Training Loss: 0.279..  Validation Loss: 0.383..  Validation Accuracy: 0.866
# Epoch: 9/20..  Training Loss: 0.280..  Validation Loss: 0.361..  Validation Accuracy: 0.877
# Epoch: 10/20..  Training Loss: 0.266..  Validation Loss: 0.370..  Validation Accuracy: 0.877
# Epoch: 11/20..  Training Loss: 0.262..  Validation Loss: 0.411..  Validation Accuracy: 0.867
# Epoch: 12/20..  Training Loss: 0.254..  Validation Loss: 0.371..  Validation Accuracy: 0.876
# Epoch: 13/20..  Training Loss: 0.244..  Validation Loss: 0.396..  Validation Accuracy: 0.878
# Epoch: 14/20..  Training Loss: 0.244..  Validation Loss: 0.387..  Validation Accuracy: 0.878
# Epoch: 15/20..  Training Loss: 0.238..  Validation Loss: 0.367..  Validation Accuracy: 0.876
# Epoch: 16/20..  Training Loss: 0.229..  Validation Loss: 0.394..  Validation Accuracy: 0.879
# Epoch: 17/20..  Training Loss: 0.229..  Validation Loss: 0.372..  Validation Accuracy: 0.882
# Epoch: 18/20..  Training Loss: 0.227..  Validation Loss: 0.371..  Validation Accuracy: 0.884
# Epoch: 19/20..  Training Loss: 0.220..  Validation Loss: 0.380..  Validation Accuracy: 0.880
# Epoch: 20/20..  Training Loss: 0.219..  Validation Loss: 0.401..  Validation Accuracy: 0.884

# %%
from torch import topk
import numpy as np


model = Classifier()
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

epochs = 5
steps = 0

test_batch_loss = []

train_losses, test_losses = [], []
for e in range(epochs):
    running_loss = []
    running_accuracy = 0
    with torch.no_grad():
        for images, labels in testloader:
            
            optimizer.zero_grad()
            
            log_ps = model(images)
            top_p,top_class = topk(log_ps,1,dim=1)
            equals = top_class == labels.view(*top_class.shape)
            accuracy = torch.mean(equals.type(torch.FloatTensor))
            print(f'Batch Accuracy: {accuracy.item()*100}%')
            
            
            loss = criterion(log_ps, labels)

            
            running_loss.append(loss.item())
    
    
        else:
            ## TODO: Implement the validation pass and print out the validation accuracy
            test_batch_loss.append(np.mean(running_loss))
            print(f'Accuracy: {accuracy.item()*100}%')
# Out:
# Batch Accuracy: 10.9375%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 18.75%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 3.125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 18.75%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 0.0%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 3.125%
# Batch Accuracy: 18.75%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 3.125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 18.75%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 3.125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 3.125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 3.125%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 3.125%
# Batch Accuracy: 20.3125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 3.125%
# Batch Accuracy: 20.3125%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 15.625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 3.125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 15.625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 15.625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 0.0%
# Accuracy: 0.0%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 3.125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 12.5%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 18.75%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 3.125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 15.625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 3.125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 18.75%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 3.125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 20.3125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 3.125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 3.125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 18.75%
# Accuracy: 18.75%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 0.0%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 15.625%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 3.125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 0.0%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 3.125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 15.625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 3.125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 3.125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 3.125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 3.125%
# Batch Accuracy: 3.125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 3.125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 15.625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 15.625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 3.125%
# Batch Accuracy: 3.125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 3.125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 15.625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 12.5%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 21.875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 3.125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 0.0%
# Batch Accuracy: 6.25%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 12.5%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 3.125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 3.125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 15.625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 15.625%
# Batch Accuracy: 3.125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 3.125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 18.75%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 12.5%
# Batch Accuracy: 12.5%
# Batch Accuracy: 12.5%
# Batch Accuracy: 3.125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 15.625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 15.625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 6.25%
# Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 15.625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 15.625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 3.125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 20.3125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 3.125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 20.3125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 12.5%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 3.125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Accuracy: 6.25%

# %%
import numpy as np
import matplotlib.pyplot as plt


plt.plot(range(20),train_losses,range(20),test_losses)
plt.xlabel("Epochs")
plt.ylabel("Loss")

# lbl =

# plt.xticks(list(range(20)),labels = )
plt.show()

# %% [markdown]
# ## Overfitting
#
# If we look at the training and validation losses as we train the network, we can see a phenomenon known as overfitting.
#
# <img src='assets/overfitting.png' width=450px>
#
# The network learns the training set better and better, resulting in lower training losses. However, it starts having problems generalizing to data outside the training set leading to the validation loss increasing. The ultimate goal of any deep learning model is to make predictions on new data, so we should strive to get the lowest validation loss possible. One option is to use the version of the model with the lowest validation loss, here the one around 8-10 training epochs. This strategy is called *early-stopping*. In practice, you'd save the model frequently as you're training then later choose the model with the lowest validation loss.
#
# The most common method to reduce overfitting (outside of early-stopping) is *dropout*, where we randomly drop input units. This forces the network to share information between weights, increasing it's ability to generalize to new data. Adding dropout in PyTorch is straightforward using the [`nn.Dropout`](https://pytorch.org/docs/stable/nn.html#torch.nn.Dropout) module.
#
# ```python
# class Classifier(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(784, 256)
#         self.fc2 = nn.Linear(256, 128)
#         self.fc3 = nn.Linear(128, 64)
#         self.fc4 = nn.Linear(64, 10)
#
#         # Dropout module with 0.2 drop probability
#         self.dropout = nn.Dropout(p=0.2)
#
#     def forward(self, x):
#         # make sure input tensor is flattened
#         x = x.view(x.shape[0], -1)
#
#         # Now with dropout
#         x = self.dropout(F.relu(self.fc1(x)))
#         x = self.dropout(F.relu(self.fc2(x)))
#         x = self.dropout(F.relu(self.fc3(x)))
#
#         # output so no dropout here
#         x = F.log_softmax(self.fc4(x), dim=1)
#
#         return x
# ```
#
# During training we want to use dropout to prevent overfitting, but during inference we want to use the entire network. So, we need to turn off dropout during validation, testing, and whenever we're using the network to make predictions. To do this, you use `model.eval()`. This sets the model to evaluation mode where the dropout probability is 0. You can turn dropout back on by setting the model to train mode with `model.train()`. In general, the pattern for the validation loop will look like this, where you turn off gradients, set the model to evaluation mode, calculate the validation loss and metric, then set the model back to train mode.
#
# ```python
# # turn off gradients
# with torch.no_grad():
#
#     # set model to evaluation mode
#     model.eval()
#
#     # validation pass here
#     for images, labels in testloader:
#         ...
#
# # set model back to train mode
# model.train()
# ```

# %% [markdown]
# > **Exercise:** Add dropout to your model and train it on Fashion-MNIST again. See if you can get a lower validation loss or higher accuracy.

# %%
## TODO: Define your model with dropout added

# %%
## TODO: Train your model with dropout, and monitor the training progress with the validation loss and accuracy

# %% [markdown]
# ## Inference
#
# Now that the model is trained, we can use it for inference. We've done this before, but now we need to remember to set the model in inference mode with `model.eval()`. You'll also want to turn off autograd with the `torch.no_grad()` context.

# %%
# Import helper module (should be in the repo)
import helper

# Test out your network!

model.eval()

dataiter = iter(testloader)
images, labels = next(dataiter)
img = images[0]
# Convert 2D image to 1D vector
img = img.view(1, 784)

# Calculate the class probabilities (softmax) for img
with torch.no_grad():
    output = model.forward(img)

ps = torch.exp(output)

# Plot the image and probabilities
helper.view_classify(img.view(1, 28, 28), ps, version='Fashion')

# %% [markdown]
# ## Next Up!
#
# In the next part, I'll show you how to save your trained models. In general, you won't want to train a model every time you need it. Instead, you'll train once, save it, then load the model when you want to train more or use if for inference.
