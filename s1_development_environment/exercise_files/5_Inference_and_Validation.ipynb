# %% [markdown]
# # Inference and Validation
#
# Now that you have a trained network, you can use it for making predictions. This is typically called **inference**, a term borrowed from statistics. However, neural networks have a tendency to perform *too well* on the training data and aren't able to generalize to data that hasn't been seen before. This is called **overfitting** and it impairs inference performance. To test for overfitting while training, we measure the performance on data not in the training set called the **validation** set. We avoid overfitting through regularization such as dropout while monitoring the validation performance during training. In this notebook, I'll show you how to do this in PyTorch.
#
# As usual, let's start by loading the dataset through torchvision. You'll learn more about torchvision and loading data in a later part. This time we'll be taking advantage of the test set which you can get by setting `train=False` here:
#
# ```python
# testset = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', download=True, train=False, transform=transform)
# ```
#
# The test set contains images just like the training set. Typically you'll see 10-20% of the original dataset held out for testing and validation with the rest being used for training.

# %%
import torch
from torchvision import datasets, transforms

# Define a transform to normalize the data
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5,), (0.5,))])
# Download and load the training data
trainset = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', download=True, train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

# Download and load the test data
testset = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', download=True, train=False, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=True)

# %% [markdown]
# Here I'll create a model like normal, using the same one from my solution for part 4.

# %%
from torch import nn, optim
import torch.nn.functional as F

class Classifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 10)
        
    def forward(self, x):
        # make sure input tensor is flattened
        x = x.view(x.shape[0], -1)
        
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.log_softmax(self.fc4(x), dim=1)
        
        return x

# %% [markdown]
# The goal of validation is to measure the model's performance on data that isn't part of the training set. Performance here is up to the developer to define though. Typically this is just accuracy, the percentage of classes the network predicted correctly. Other options are [precision and recall](https://en.wikipedia.org/wiki/Precision_and_recall#Definition_(classification_context)) and top-5 error rate. We'll focus on accuracy here. First I'll do a forward pass with one batch from the test set.

# %%
model = Classifier()

images, labels = next(iter(testloader))
# Get the class probabilities
ps = torch.exp(model(images))
# Make sure the shape is appropriate, we should get 10 class probabilities for 64 examples
print(ps.shape)
# Out:
# torch.Size([64, 10])

# %% [markdown]
# With the probabilities, we can get the most likely class using the `ps.topk` method. This returns the $k$ highest values. Since we just want the most likely class, we can use `ps.topk(1)`. This returns a tuple of the top-$k$ values and the top-$k$ indices. If the highest value is the fifth element, we'll get back 4 as the index.

# %%
top_p, top_class = ps.topk(1, dim=1)
# Look at the most likely classes for the first 10 examples
print(top_class[:10,:])
# Out:
# tensor([[4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4]])

# %% [markdown]
# Now we can check if the predicted classes match the labels. This is simple to do by equating `top_class` and `labels`, but we have to be careful of the shapes. Here `top_class` is a 2D tensor with shape `(64, 1)` while `labels` is 1D with shape `(64)`. To get the equality to work out the way we want, `top_class` and `labels` must have the same shape.
#
# If we do
#
# ```python
# equals = top_class == labels
# ```
#
# `equals` will have shape `(64, 64)`, try it yourself. What it's doing is comparing the one element in each row of `top_class` with each element in `labels` which returns 64 True/False boolean values for each row.

# %%
equals = top_class == labels.view(*top_class.shape)

# %% [markdown]
# Now we need to calculate the percentage of correct predictions. `equals` has binary values, either 0 or 1. This means that if we just sum up all the values and divide by the number of values, we get the percentage of correct predictions. This is the same operation as taking the mean, so we can get the accuracy with a call to `torch.mean`. If only it was that simple. If you try `torch.mean(equals)`, you'll get an error
#
# ```
# RuntimeError: mean is not implemented for type torch.ByteTensor
# ```
#
# This happens because `equals` has type `torch.ByteTensor` but `torch.mean` isn't implemented for tensors with that type. So we'll need to convert `equals` to a float tensor. Note that when we take `torch.mean` it returns a scalar tensor, to get the actual value as a float we'll need to do `accuracy.item()`.

# %%
accuracy = torch.mean(equals.type(torch.FloatTensor))
print(f'Accuracy: {accuracy.item()*100}%')
# Out:
# Accuracy: 6.25%

# %% [markdown]
# The network is untrained so it's making random guesses and we should see an accuracy around 10%. Now let's train our network and include our validation pass so we can measure how well the network is performing on the test set. Since we're not updating our parameters in the validation pass, we can speed up our code by turning off gradients using `torch.no_grad()`:
#
# ```python
# # turn off gradients
# with torch.no_grad():
#     # validation pass here
#     for images, labels in testloader:
#         ...
# ```
#
# >**Exercise:** Implement the validation loop below and print out the total accuracy after the loop. You can largely copy and paste the code from above, but I suggest typing it in because writing it out yourself is essential for building the skill. In general you'll always learn more by typing it rather than copy-pasting. You should be able to get an accuracy above 80%.

# %%
model = Classifier()
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

epochs = 5
steps = 0

train_losses, test_losses = [], []
for e in range(epochs):
    running_loss = 0
    for images, labels in trainloader:
        
        optimizer.zero_grad()
        
        log_ps = model(images)
        loss = criterion(log_ps, labels)
        print(loss.item())
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()

        # Get Training Accuracy
        ps = torch.exp(log_ps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy = torch.mean(equals.type(torch.FloatTensor))
        print("Batch Training Accuracy: ",accuracy)
        
        
    else:
        ## TODO: Implement the validation pass and print out the validation accuracy
        pass
# Out:
# 2.2958197593688965
# Batch Training Accuracy:  tensor(0.0781)
# 2.1897692680358887
# Batch Training Accuracy:  tensor(0.1094)
# 2.0933444499969482
# Batch Training Accuracy:  tensor(0.2969)
# 1.9750828742980957
# Batch Training Accuracy:  tensor(0.3438)
# 1.7752951383590698
# Batch Training Accuracy:  tensor(0.3906)
# 1.6468982696533203
# Batch Training Accuracy:  tensor(0.4688)
# 1.6097662448883057
# Batch Training Accuracy:  tensor(0.3594)
# 1.5315701961517334
# Batch Training Accuracy:  tensor(0.3750)
# 1.1729952096939087
# Batch Training Accuracy:  tensor(0.5312)
# 1.279517650604248
# Batch Training Accuracy:  tensor(0.5000)
# 1.1665475368499756
# Batch Training Accuracy:  tensor(0.5625)
# 1.1994658708572388
# Batch Training Accuracy:  tensor(0.5625)
# 1.1798043251037598
# Batch Training Accuracy:  tensor(0.5625)
# 1.0615984201431274
# Batch Training Accuracy:  tensor(0.5469)
# 0.9215893149375916
# Batch Training Accuracy:  tensor(0.7031)
# 0.9156370162963867
# Batch Training Accuracy:  tensor(0.6875)
# 1.0260752439498901
# Batch Training Accuracy:  tensor(0.5938)
# 0.8737782835960388
# Batch Training Accuracy:  tensor(0.6250)
# 1.0313982963562012
# Batch Training Accuracy:  tensor(0.5938)
# 0.7675830125808716
# Batch Training Accuracy:  tensor(0.6250)
# 0.8336471915245056
# Batch Training Accuracy:  tensor(0.7031)
# 1.0947333574295044
# Batch Training Accuracy:  tensor(0.6250)
# 0.8947277665138245
# Batch Training Accuracy:  tensor(0.7344)
# 0.8679072856903076
# Batch Training Accuracy:  tensor(0.6406)
# 0.7379437685012817
# Batch Training Accuracy:  tensor(0.7031)
# 0.7953857183456421
# Batch Training Accuracy:  tensor(0.6406)
# 0.8533509969711304
# Batch Training Accuracy:  tensor(0.6875)
# 0.7087242603302002
# Batch Training Accuracy:  tensor(0.7656)
# 0.8224191665649414
# Batch Training Accuracy:  tensor(0.6562)
# 0.7393975257873535
# Batch Training Accuracy:  tensor(0.7344)
# 0.8196362257003784
# Batch Training Accuracy:  tensor(0.7031)
# 0.6724680066108704
# Batch Training Accuracy:  tensor(0.7812)
# 0.8384522199630737
# Batch Training Accuracy:  tensor(0.6250)
# 0.9148057699203491
# Batch Training Accuracy:  tensor(0.5781)
# 1.0233021974563599
# Batch Training Accuracy:  tensor(0.5781)
# 0.7669850587844849
# Batch Training Accuracy:  tensor(0.6406)
# 0.7678444981575012
# Batch Training Accuracy:  tensor(0.6562)
# 0.6641579270362854
# Batch Training Accuracy:  tensor(0.7188)
# 0.8466619253158569
# Batch Training Accuracy:  tensor(0.7344)
# 0.7704843282699585
# Batch Training Accuracy:  tensor(0.7656)
# 0.7681012153625488
# Batch Training Accuracy:  tensor(0.7500)
# 0.6771058440208435
# Batch Training Accuracy:  tensor(0.6875)
# 0.7577610015869141
# Batch Training Accuracy:  tensor(0.6562)
# 0.6414168477058411
# Batch Training Accuracy:  tensor(0.7500)
# 0.7591171264648438
# Batch Training Accuracy:  tensor(0.7344)
# 0.8096475601196289
# Batch Training Accuracy:  tensor(0.7656)
# 0.6944767236709595
# Batch Training Accuracy:  tensor(0.7344)
# 0.5536313056945801
# Batch Training Accuracy:  tensor(0.7969)
# 0.6103223562240601
# Batch Training Accuracy:  tensor(0.7500)
# 0.5958094000816345
# Batch Training Accuracy:  tensor(0.7188)
# 0.666934609413147
# Batch Training Accuracy:  tensor(0.6250)
# 0.8070458173751831
# Batch Training Accuracy:  tensor(0.7344)
# 0.6892313957214355
# Batch Training Accuracy:  tensor(0.6875)
# 0.6406800150871277
# Batch Training Accuracy:  tensor(0.7969)
# 0.6059858798980713
# Batch Training Accuracy:  tensor(0.7812)
# 0.8536199927330017
# Batch Training Accuracy:  tensor(0.6875)
# 0.6856603026390076
# Batch Training Accuracy:  tensor(0.7500)
# 0.6829320192337036
# Batch Training Accuracy:  tensor(0.6719)
# 0.605766236782074
# Batch Training Accuracy:  tensor(0.7969)
# 0.6281659603118896
# Batch Training Accuracy:  tensor(0.7656)
# 0.7386408448219299
# Batch Training Accuracy:  tensor(0.7188)
# 0.7699333429336548
# Batch Training Accuracy:  tensor(0.6719)
# 0.6176702380180359
# Batch Training Accuracy:  tensor(0.6875)
# 0.6706473231315613
# Batch Training Accuracy:  tensor(0.7656)
# 0.6503610610961914
# Batch Training Accuracy:  tensor(0.7188)
# 0.9454899430274963
# Batch Training Accuracy:  tensor(0.5938)
# 0.6035301685333252
# Batch Training Accuracy:  tensor(0.7344)
# 0.6410332918167114
# Batch Training Accuracy:  tensor(0.7500)
# 0.6600340008735657
# Batch Training Accuracy:  tensor(0.7656)
# 0.8149816393852234
# Batch Training Accuracy:  tensor(0.7031)
# 0.7282441854476929
# Batch Training Accuracy:  tensor(0.7344)
# 0.7760521173477173
# Batch Training Accuracy:  tensor(0.6406)
# 0.655204713344574
# Batch Training Accuracy:  tensor(0.6875)
# 0.7782894372940063
# Batch Training Accuracy:  tensor(0.6719)
# 0.5251973867416382
# Batch Training Accuracy:  tensor(0.8281)
# 0.7854165434837341
# Batch Training Accuracy:  tensor(0.6719)
# 0.763375997543335
# Batch Training Accuracy:  tensor(0.7188)
# 0.552345871925354
# Batch Training Accuracy:  tensor(0.7656)
# 0.6542186737060547
# Batch Training Accuracy:  tensor(0.7031)
# 0.6858642101287842
# Batch Training Accuracy:  tensor(0.6406)
# 0.8345531821250916
# Batch Training Accuracy:  tensor(0.6094)
# 0.7470070719718933
# Batch Training Accuracy:  tensor(0.7500)
# 0.6265023350715637
# Batch Training Accuracy:  tensor(0.7656)
# 0.8667201995849609
# Batch Training Accuracy:  tensor(0.7500)
# 0.8241270184516907
# Batch Training Accuracy:  tensor(0.7188)
# 0.6007656455039978
# Batch Training Accuracy:  tensor(0.8125)
# 0.5471946597099304
# Batch Training Accuracy:  tensor(0.8438)
# 0.5819680690765381
# Batch Training Accuracy:  tensor(0.7812)
# 0.42377710342407227
# Batch Training Accuracy:  tensor(0.8750)
# 0.5026072859764099
# Batch Training Accuracy:  tensor(0.7656)
# 0.5109993815422058
# Batch Training Accuracy:  tensor(0.8594)
# 0.5302406549453735
# Batch Training Accuracy:  tensor(0.8594)
# 0.6075053215026855
# Batch Training Accuracy:  tensor(0.7344)
# 0.6936267018318176
# Batch Training Accuracy:  tensor(0.7031)
# 0.528433084487915
# Batch Training Accuracy:  tensor(0.8125)
# 0.6030661463737488
# Batch Training Accuracy:  tensor(0.7969)
# 0.46930280327796936
# Batch Training Accuracy:  tensor(0.8594)
# 0.5258224606513977
# Batch Training Accuracy:  tensor(0.8438)
# 0.6582311391830444
# Batch Training Accuracy:  tensor(0.7344)
# 0.6582266092300415
# Batch Training Accuracy:  tensor(0.7188)
# 1.0445154905319214
# Batch Training Accuracy:  tensor(0.5938)
# 0.49520960450172424
# Batch Training Accuracy:  tensor(0.7969)
# 0.5451450347900391
# Batch Training Accuracy:  tensor(0.7969)
# 0.774549126625061
# Batch Training Accuracy:  tensor(0.7031)
# 0.5987446308135986
# Batch Training Accuracy:  tensor(0.7500)
# 0.5559284687042236
# Batch Training Accuracy:  tensor(0.7969)
# 0.7005429267883301
# Batch Training Accuracy:  tensor(0.6562)
# 0.5961880087852478
# Batch Training Accuracy:  tensor(0.7344)
# 0.617957592010498
# Batch Training Accuracy:  tensor(0.7344)
# 0.3961845934391022
# Batch Training Accuracy:  tensor(0.8281)
# 0.6771402955055237
# Batch Training Accuracy:  tensor(0.7031)
# 0.6788628101348877
# Batch Training Accuracy:  tensor(0.6719)
# 0.6207188963890076
# Batch Training Accuracy:  tensor(0.7500)
# 0.38330093026161194
# Batch Training Accuracy:  tensor(0.8594)
# 0.5124374032020569
# Batch Training Accuracy:  tensor(0.7969)
# 0.753601610660553
# Batch Training Accuracy:  tensor(0.7500)
# 0.6050639748573303
# Batch Training Accuracy:  tensor(0.7500)
# 0.5428271889686584
# Batch Training Accuracy:  tensor(0.7812)
# 0.5107752680778503
# Batch Training Accuracy:  tensor(0.7500)
# 0.43925097584724426
# Batch Training Accuracy:  tensor(0.8594)
# 0.6201656460762024
# Batch Training Accuracy:  tensor(0.7812)
# 0.8641643524169922
# Batch Training Accuracy:  tensor(0.7031)
# 0.5349034070968628
# Batch Training Accuracy:  tensor(0.7656)
# 0.6290525197982788
# Batch Training Accuracy:  tensor(0.7500)
# 0.5339442491531372
# Batch Training Accuracy:  tensor(0.8125)
# 0.6722596287727356
# Batch Training Accuracy:  tensor(0.8281)
# 0.3428337872028351
# Batch Training Accuracy:  tensor(0.8594)
# 0.6336508393287659
# Batch Training Accuracy:  tensor(0.7188)
# 0.7956334948539734
# Batch Training Accuracy:  tensor(0.7188)
# 0.8121660351753235
# Batch Training Accuracy:  tensor(0.6562)
# 0.6069284081459045
# Batch Training Accuracy:  tensor(0.8125)
# 0.9272172451019287
# Batch Training Accuracy:  tensor(0.6406)
# 0.47921526432037354
# Batch Training Accuracy:  tensor(0.7969)
# 0.6536096334457397
# Batch Training Accuracy:  tensor(0.7656)
# 0.4912319779396057
# Batch Training Accuracy:  tensor(0.8594)
# 0.46894532442092896
# Batch Training Accuracy:  tensor(0.8125)
# 0.5131339430809021
# Batch Training Accuracy:  tensor(0.7656)
# 0.5853360891342163
# Batch Training Accuracy:  tensor(0.8438)
# 0.8827564120292664
# Batch Training Accuracy:  tensor(0.6406)
# 0.4729897677898407
# Batch Training Accuracy:  tensor(0.8438)
# 0.6780033111572266
# Batch Training Accuracy:  tensor(0.7031)
# 0.5054463148117065
# Batch Training Accuracy:  tensor(0.7969)
# 0.4741292893886566
# Batch Training Accuracy:  tensor(0.8438)
# 0.5588233470916748
# Batch Training Accuracy:  tensor(0.7969)
# 0.5335371494293213
# Batch Training Accuracy:  tensor(0.8125)
# 0.5727017521858215
# Batch Training Accuracy:  tensor(0.7500)
# 0.444748193025589
# Batch Training Accuracy:  tensor(0.9062)
# 0.7449162602424622
# Batch Training Accuracy:  tensor(0.8125)
# 0.6739656329154968
# Batch Training Accuracy:  tensor(0.7969)
# 0.39275896549224854
# Batch Training Accuracy:  tensor(0.8594)
# 0.47057339549064636
# Batch Training Accuracy:  tensor(0.8281)
# 0.426639199256897
# Batch Training Accuracy:  tensor(0.8594)
# 0.6463941931724548
# Batch Training Accuracy:  tensor(0.7500)
# 0.5294126272201538
# Batch Training Accuracy:  tensor(0.8125)
# 0.5377792119979858
# Batch Training Accuracy:  tensor(0.8125)
# 0.6988951563835144
# Batch Training Accuracy:  tensor(0.7656)
# 0.5248180627822876
# Batch Training Accuracy:  tensor(0.7969)
# 0.4621633291244507
# Batch Training Accuracy:  tensor(0.8438)
# 0.7065608501434326
# Batch Training Accuracy:  tensor(0.7031)
# 0.3835040330886841
# Batch Training Accuracy:  tensor(0.8438)
# 0.6389362215995789
# Batch Training Accuracy:  tensor(0.7500)
# 0.4038940668106079
# Batch Training Accuracy:  tensor(0.8906)
# 0.8173603415489197
# Batch Training Accuracy:  tensor(0.6875)
# 0.7072190642356873
# Batch Training Accuracy:  tensor(0.7344)
# 0.6596322655677795
# Batch Training Accuracy:  tensor(0.7656)
# 0.6935364603996277
# Batch Training Accuracy:  tensor(0.8281)
# 0.4116438627243042
# Batch Training Accuracy:  tensor(0.8906)
# 0.38449719548225403
# Batch Training Accuracy:  tensor(0.8438)
# 0.8627779483795166
# Batch Training Accuracy:  tensor(0.7031)
# 0.4248712658882141
# Batch Training Accuracy:  tensor(0.8281)
# 0.6495774984359741
# Batch Training Accuracy:  tensor(0.7344)
# 0.5858206748962402
# Batch Training Accuracy:  tensor(0.8438)
# 0.6501961350440979
# Batch Training Accuracy:  tensor(0.8125)
# 0.6300655007362366
# Batch Training Accuracy:  tensor(0.8125)
# 0.5442690849304199
# Batch Training Accuracy:  tensor(0.8281)
# 0.5768200159072876
# Batch Training Accuracy:  tensor(0.7656)
# 0.5711482167243958
# Batch Training Accuracy:  tensor(0.7656)
# 0.4864673614501953
# Batch Training Accuracy:  tensor(0.7812)
# 0.576433002948761
# Batch Training Accuracy:  tensor(0.7812)
# 0.4842054545879364
# Batch Training Accuracy:  tensor(0.7969)
# 0.7958248853683472
# Batch Training Accuracy:  tensor(0.7500)
# 0.6751317977905273
# Batch Training Accuracy:  tensor(0.7500)
# 0.5064815282821655
# Batch Training Accuracy:  tensor(0.8125)
# 0.4227871894836426
# Batch Training Accuracy:  tensor(0.8750)
# 0.8130303621292114
# Batch Training Accuracy:  tensor(0.7031)
# 0.5667941570281982
# Batch Training Accuracy:  tensor(0.7969)
# 0.447999507188797
# Batch Training Accuracy:  tensor(0.8438)
# 0.6152241826057434
# Batch Training Accuracy:  tensor(0.7500)
# 0.5065423250198364
# Batch Training Accuracy:  tensor(0.7969)
# 0.6337659358978271
# Batch Training Accuracy:  tensor(0.7344)
# 0.6513018012046814
# Batch Training Accuracy:  tensor(0.7812)
# 0.6734873056411743
# Batch Training Accuracy:  tensor(0.7656)
# 0.707160234451294
# Batch Training Accuracy:  tensor(0.6875)
# 0.5010372996330261
# Batch Training Accuracy:  tensor(0.7969)
# 0.4465673565864563
# Batch Training Accuracy:  tensor(0.8281)
# 0.729525089263916
# Batch Training Accuracy:  tensor(0.7344)
# 0.5661796927452087
# Batch Training Accuracy:  tensor(0.7656)
# 0.4152575433254242
# Batch Training Accuracy:  tensor(0.8906)
# 0.8323673009872437
# Batch Training Accuracy:  tensor(0.6875)
# 0.4908766448497772
# Batch Training Accuracy:  tensor(0.7500)
# 0.6097249388694763
# Batch Training Accuracy:  tensor(0.7344)
# 0.500436007976532
# Batch Training Accuracy:  tensor(0.8125)
# 0.467395156621933
# Batch Training Accuracy:  tensor(0.8281)
# 0.48753806948661804
# Batch Training Accuracy:  tensor(0.8438)
# 0.8988580703735352
# Batch Training Accuracy:  tensor(0.6406)
# 0.8570051789283752
# Batch Training Accuracy:  tensor(0.7188)
# 0.5929809808731079
# Batch Training Accuracy:  tensor(0.7656)
# 0.7566247582435608
# Batch Training Accuracy:  tensor(0.6719)
# 0.5306116342544556
# Batch Training Accuracy:  tensor(0.7969)
# 0.46265310049057007
# Batch Training Accuracy:  tensor(0.8438)
# 0.5531575679779053
# Batch Training Accuracy:  tensor(0.8125)
# 0.5757025480270386
# Batch Training Accuracy:  tensor(0.7656)
# 0.46328845620155334
# Batch Training Accuracy:  tensor(0.8594)
# 0.6219871640205383
# Batch Training Accuracy:  tensor(0.7969)
# 0.5280579924583435
# Batch Training Accuracy:  tensor(0.8281)
# 0.39461562037467957
# Batch Training Accuracy:  tensor(0.8594)
# 0.6700263619422913
# Batch Training Accuracy:  tensor(0.7500)
# 0.6100940704345703
# Batch Training Accuracy:  tensor(0.8281)
# 0.7346363067626953
# Batch Training Accuracy:  tensor(0.7031)
# 0.4352661669254303
# Batch Training Accuracy:  tensor(0.8125)
# 0.5758472084999084
# Batch Training Accuracy:  tensor(0.7812)
# 0.45049265027046204
# Batch Training Accuracy:  tensor(0.8125)
# 0.6993008255958557
# Batch Training Accuracy:  tensor(0.8125)
# 0.4330286979675293
# Batch Training Accuracy:  tensor(0.8438)
# 0.5699959397315979
# Batch Training Accuracy:  tensor(0.8281)
# 0.5894436240196228
# Batch Training Accuracy:  tensor(0.8281)
# 0.4058106243610382
# Batch Training Accuracy:  tensor(0.8281)
# 0.4948716461658478
# Batch Training Accuracy:  tensor(0.8281)
# 0.5056275129318237
# Batch Training Accuracy:  tensor(0.8281)
# 0.45000192523002625
# Batch Training Accuracy:  tensor(0.8438)
# 0.5947034955024719
# Batch Training Accuracy:  tensor(0.7812)
# 0.5286978483200073
# Batch Training Accuracy:  tensor(0.7969)
# 0.5211081504821777
# Batch Training Accuracy:  tensor(0.7812)
# 0.5977472066879272
# Batch Training Accuracy:  tensor(0.7969)
# 0.7213737964630127
# Batch Training Accuracy:  tensor(0.7812)
# 0.5044759511947632
# Batch Training Accuracy:  tensor(0.7656)
# 0.600735068321228
# Batch Training Accuracy:  tensor(0.7969)
# 0.5526965856552124
# Batch Training Accuracy:  tensor(0.7656)
# 0.6619002223014832
# Batch Training Accuracy:  tensor(0.7344)
# 0.7625014781951904
# Batch Training Accuracy:  tensor(0.7344)
# 0.8798750638961792
# Batch Training Accuracy:  tensor(0.7500)
# 0.443848192691803
# Batch Training Accuracy:  tensor(0.8281)
# 0.3193333148956299
# Batch Training Accuracy:  tensor(0.9062)
# 0.5671650171279907
# Batch Training Accuracy:  tensor(0.7812)
# 0.46639081835746765
# Batch Training Accuracy:  tensor(0.8750)
# 0.4694252014160156
# Batch Training Accuracy:  tensor(0.7969)
# 0.5385696887969971
# Batch Training Accuracy:  tensor(0.7812)
# 0.8765061497688293
# Batch Training Accuracy:  tensor(0.6719)
# 0.4798602759838104
# Batch Training Accuracy:  tensor(0.7812)
# 0.6955664157867432
# Batch Training Accuracy:  tensor(0.7500)
# 0.49860879778862
# Batch Training Accuracy:  tensor(0.8438)
# 0.474758505821228
# Batch Training Accuracy:  tensor(0.8281)
# 0.4957290291786194
# Batch Training Accuracy:  tensor(0.8594)
# 0.4652691185474396
# Batch Training Accuracy:  tensor(0.8281)
# 0.5004558563232422
# Batch Training Accuracy:  tensor(0.8281)
# 0.5570648908615112
# Batch Training Accuracy:  tensor(0.7500)
# 0.4502623677253723
# Batch Training Accuracy:  tensor(0.8750)
# 0.4040290415287018
# Batch Training Accuracy:  tensor(0.8594)
# 0.4080500602722168
# Batch Training Accuracy:  tensor(0.8906)
# 0.5742454528808594
# Batch Training Accuracy:  tensor(0.7656)
# 0.5010788440704346
# Batch Training Accuracy:  tensor(0.8438)
# 0.3689267635345459
# Batch Training Accuracy:  tensor(0.8750)
# 0.44017261266708374
# Batch Training Accuracy:  tensor(0.8281)
# 0.4642483592033386
# Batch Training Accuracy:  tensor(0.8594)
# 0.505181074142456
# Batch Training Accuracy:  tensor(0.8281)
# 0.3642461597919464
# Batch Training Accuracy:  tensor(0.8906)
# 0.39576178789138794
# Batch Training Accuracy:  tensor(0.8438)
# 0.4434524178504944
# Batch Training Accuracy:  tensor(0.8281)
# 0.8467729687690735
# Batch Training Accuracy:  tensor(0.7031)
# 0.5171852707862854
# Batch Training Accuracy:  tensor(0.7969)
# 0.4982874095439911
# Batch Training Accuracy:  tensor(0.7969)
# 0.4249535799026489
# Batch Training Accuracy:  tensor(0.8594)
# 0.565650463104248
# Batch Training Accuracy:  tensor(0.7812)
# 0.3515397012233734
# Batch Training Accuracy:  tensor(0.9062)
# 0.3985663652420044
# Batch Training Accuracy:  tensor(0.8594)
# 0.5972614884376526
# Batch Training Accuracy:  tensor(0.7812)
# 0.721757173538208
# Batch Training Accuracy:  tensor(0.7344)
# 0.4415547847747803
# Batch Training Accuracy:  tensor(0.8906)
# 0.45698732137680054
# Batch Training Accuracy:  tensor(0.8438)
# 0.5801759362220764
# Batch Training Accuracy:  tensor(0.7188)
# 0.6054826378822327
# Batch Training Accuracy:  tensor(0.7812)
# 0.5284733772277832
# Batch Training Accuracy:  tensor(0.8125)
# 0.7875422835350037
# Batch Training Accuracy:  tensor(0.6875)
# 0.5451761484146118
# Batch Training Accuracy:  tensor(0.7812)
# 0.6238281726837158
# Batch Training Accuracy:  tensor(0.7656)
# 0.35764217376708984
# Batch Training Accuracy:  tensor(0.8438)
# 0.4710347354412079
# Batch Training Accuracy:  tensor(0.8125)
# 0.7156981825828552
# Batch Training Accuracy:  tensor(0.7656)
# 0.31668227910995483
# Batch Training Accuracy:  tensor(0.8750)
# 0.6304662823677063
# Batch Training Accuracy:  tensor(0.8281)
# 0.515313982963562
# Batch Training Accuracy:  tensor(0.8125)
# 0.6101265549659729
# Batch Training Accuracy:  tensor(0.7812)
# 0.5236336588859558
# Batch Training Accuracy:  tensor(0.7969)
# 0.5408439636230469
# Batch Training Accuracy:  tensor(0.7500)
# 0.846422016620636
# Batch Training Accuracy:  tensor(0.7656)
# 0.5423453450202942
# Batch Training Accuracy:  tensor(0.7656)
# 0.4179433584213257
# Batch Training Accuracy:  tensor(0.8594)
# 0.5879528522491455
# Batch Training Accuracy:  tensor(0.7656)
# 0.40742847323417664
# Batch Training Accuracy:  tensor(0.8594)
# 0.5168072581291199
# Batch Training Accuracy:  tensor(0.7812)
# 0.4633892774581909
# Batch Training Accuracy:  tensor(0.8594)
# 0.4567352533340454
# Batch Training Accuracy:  tensor(0.8125)
# 0.6699624061584473
# Batch Training Accuracy:  tensor(0.7656)
# 0.5800834894180298
# Batch Training Accuracy:  tensor(0.7656)
# 0.32975637912750244
# Batch Training Accuracy:  tensor(0.8750)
# 0.5883389711380005
# Batch Training Accuracy:  tensor(0.7812)
# 0.46686771512031555
# Batch Training Accuracy:  tensor(0.8594)
# 0.6424282193183899
# Batch Training Accuracy:  tensor(0.7344)
# 0.6108070015907288
# Batch Training Accuracy:  tensor(0.7812)
# 0.4987001121044159
# Batch Training Accuracy:  tensor(0.8594)
# 0.48643791675567627
# Batch Training Accuracy:  tensor(0.8281)
# 0.3985154330730438
# Batch Training Accuracy:  tensor(0.8906)
# 0.25998926162719727
# Batch Training Accuracy:  tensor(0.9062)
# 0.5677739381790161
# Batch Training Accuracy:  tensor(0.7969)
# 0.4130875766277313
# Batch Training Accuracy:  tensor(0.8594)
# 0.37717321515083313
# Batch Training Accuracy:  tensor(0.8594)
# 0.4458068907260895
# Batch Training Accuracy:  tensor(0.8125)
# 0.43092095851898193
# Batch Training Accuracy:  tensor(0.8750)
# 0.4703260064125061
# Batch Training Accuracy:  tensor(0.8281)
# 0.3530425727367401
# Batch Training Accuracy:  tensor(0.8750)
# 0.43238407373428345
# Batch Training Accuracy:  tensor(0.8281)
# 0.35906481742858887
# Batch Training Accuracy:  tensor(0.9219)
# 0.5477694869041443
# Batch Training Accuracy:  tensor(0.8125)
# 0.5545612573623657
# Batch Training Accuracy:  tensor(0.7969)
# 0.4414824843406677
# Batch Training Accuracy:  tensor(0.8125)
# 0.47495782375335693
# Batch Training Accuracy:  tensor(0.7969)
# 0.5446738004684448
# Batch Training Accuracy:  tensor(0.7656)
# 0.49988749623298645
# Batch Training Accuracy:  tensor(0.7969)
# 0.5281854271888733
# Batch Training Accuracy:  tensor(0.8281)
# 0.6950793266296387
# Batch Training Accuracy:  tensor(0.7500)
# 0.4514920115470886
# Batch Training Accuracy:  tensor(0.8438)
# 0.63167804479599
# Batch Training Accuracy:  tensor(0.7656)
# 0.2815215587615967
# Batch Training Accuracy:  tensor(0.9531)
# 0.5717372298240662
# Batch Training Accuracy:  tensor(0.7969)
# 0.5420817732810974
# Batch Training Accuracy:  tensor(0.7500)
# 0.688032329082489
# Batch Training Accuracy:  tensor(0.7344)
# 0.6621582508087158
# Batch Training Accuracy:  tensor(0.8125)
# 0.5753150582313538
# Batch Training Accuracy:  tensor(0.7812)
# 0.5033968687057495
# Batch Training Accuracy:  tensor(0.7969)
# 0.6300912499427795
# Batch Training Accuracy:  tensor(0.7812)
# 0.5896399021148682
# Batch Training Accuracy:  tensor(0.7969)
# 0.3827129602432251
# Batch Training Accuracy:  tensor(0.8594)
# 0.4389936923980713
# Batch Training Accuracy:  tensor(0.8281)
# 0.4826180636882782
# Batch Training Accuracy:  tensor(0.8750)
# 0.47189927101135254
# Batch Training Accuracy:  tensor(0.7812)
# 0.7514516115188599
# Batch Training Accuracy:  tensor(0.7344)
# 0.7548731565475464
# Batch Training Accuracy:  tensor(0.7344)
# 0.4157937169075012
# Batch Training Accuracy:  tensor(0.8281)
# 0.5091228485107422
# Batch Training Accuracy:  tensor(0.7500)
# 0.45318925380706787
# Batch Training Accuracy:  tensor(0.8125)
# 0.48156312108039856
# Batch Training Accuracy:  tensor(0.7969)
# 0.3459659218788147
# Batch Training Accuracy:  tensor(0.8906)
# 0.6327505111694336
# Batch Training Accuracy:  tensor(0.7500)
# 0.36210983991622925
# Batch Training Accuracy:  tensor(0.9062)
# 0.48045310378074646
# Batch Training Accuracy:  tensor(0.7969)
# 0.627316415309906
# Batch Training Accuracy:  tensor(0.8281)
# 0.6568118929862976
# Batch Training Accuracy:  tensor(0.7344)
# 0.45855653285980225
# Batch Training Accuracy:  tensor(0.7969)
# 0.450479120016098
# Batch Training Accuracy:  tensor(0.8438)
# 0.5849063396453857
# Batch Training Accuracy:  tensor(0.7812)
# 0.4039113223552704
# Batch Training Accuracy:  tensor(0.8906)
# 0.5456110835075378
# Batch Training Accuracy:  tensor(0.7969)
# 0.570926308631897
# Batch Training Accuracy:  tensor(0.8281)
# 0.5769423246383667
# Batch Training Accuracy:  tensor(0.7656)
# 0.4327561855316162
# Batch Training Accuracy:  tensor(0.8750)
# 0.4946865737438202
# Batch Training Accuracy:  tensor(0.7969)
# 0.41477739810943604
# Batch Training Accuracy:  tensor(0.8594)
# 0.4942360520362854
# Batch Training Accuracy:  tensor(0.7656)
# 0.42660248279571533
# Batch Training Accuracy:  tensor(0.8438)
# 0.6880078911781311
# Batch Training Accuracy:  tensor(0.7656)
# 0.5695210099220276
# Batch Training Accuracy:  tensor(0.8125)
# 0.42534345388412476
# Batch Training Accuracy:  tensor(0.8125)
# 0.31709152460098267
# Batch Training Accuracy:  tensor(0.9062)
# 0.6241104602813721
# Batch Training Accuracy:  tensor(0.7656)
# 0.5325208902359009
# Batch Training Accuracy:  tensor(0.8281)
# 0.450812965631485
# Batch Training Accuracy:  tensor(0.8438)
# 0.5888210535049438
# Batch Training Accuracy:  tensor(0.7812)
# 0.6532848477363586
# Batch Training Accuracy:  tensor(0.7812)
# 0.7376002073287964
# Batch Training Accuracy:  tensor(0.7656)
# 0.5888686776161194
# Batch Training Accuracy:  tensor(0.7500)
# 0.49469056725502014
# Batch Training Accuracy:  tensor(0.7969)
# 0.4320264160633087
# Batch Training Accuracy:  tensor(0.8750)
# 0.44192275404930115
# Batch Training Accuracy:  tensor(0.8750)
# 0.44790443778038025
# Batch Training Accuracy:  tensor(0.7969)
# 0.5308257937431335
# Batch Training Accuracy:  tensor(0.8125)
# 0.6140729784965515
# Batch Training Accuracy:  tensor(0.7812)
# 0.5165885090827942
# Batch Training Accuracy:  tensor(0.8125)
# 0.6140257120132446
# Batch Training Accuracy:  tensor(0.7812)
# 0.5288958549499512
# Batch Training Accuracy:  tensor(0.8438)
# 0.5700603127479553
# Batch Training Accuracy:  tensor(0.7344)
# 0.46588459610939026
# Batch Training Accuracy:  tensor(0.7969)
# 0.41994255781173706
# Batch Training Accuracy:  tensor(0.7969)
# 0.44989946484565735
# Batch Training Accuracy:  tensor(0.8594)
# 0.5889180302619934
# Batch Training Accuracy:  tensor(0.7500)
# 0.5077652335166931
# Batch Training Accuracy:  tensor(0.7969)
# 0.7564734816551208
# Batch Training Accuracy:  tensor(0.7656)
# 0.6653926968574524
# Batch Training Accuracy:  tensor(0.7500)
# 0.4890342056751251
# Batch Training Accuracy:  tensor(0.8125)
# 0.4500068128108978
# Batch Training Accuracy:  tensor(0.8438)
# 0.4341926574707031
# Batch Training Accuracy:  tensor(0.8281)
# 0.5882841944694519
# Batch Training Accuracy:  tensor(0.7812)
# 0.3339258134365082
# Batch Training Accuracy:  tensor(0.8906)
# 0.5662965774536133
# Batch Training Accuracy:  tensor(0.7656)
# 0.507571280002594
# Batch Training Accuracy:  tensor(0.8750)
# 0.4382175803184509
# Batch Training Accuracy:  tensor(0.8125)
# 0.37868839502334595
# Batch Training Accuracy:  tensor(0.8281)
# 0.3498508930206299
# Batch Training Accuracy:  tensor(0.8594)
# 0.42312201857566833
# Batch Training Accuracy:  tensor(0.8125)
# 0.4866124093532562
# Batch Training Accuracy:  tensor(0.7656)
# 0.5716617107391357
# Batch Training Accuracy:  tensor(0.7812)
# 0.44498878717422485
# Batch Training Accuracy:  tensor(0.8438)
# 0.6361184120178223
# Batch Training Accuracy:  tensor(0.7500)
# 0.5463684797286987
# Batch Training Accuracy:  tensor(0.7500)
# 0.6826245784759521
# Batch Training Accuracy:  tensor(0.7344)
# 0.47243067622184753
# Batch Training Accuracy:  tensor(0.8281)
# 0.6789106130599976
# Batch Training Accuracy:  tensor(0.7812)
# 0.32902589440345764
# Batch Training Accuracy:  tensor(0.9062)
# 0.6170591115951538
# Batch Training Accuracy:  tensor(0.7500)
# 0.5589832663536072
# Batch Training Accuracy:  tensor(0.7812)
# 0.3920650780200958
# Batch Training Accuracy:  tensor(0.8750)
# 0.5677292346954346
# Batch Training Accuracy:  tensor(0.8281)
# 0.6040573120117188
# Batch Training Accuracy:  tensor(0.7812)
# 0.4193146228790283
# Batch Training Accuracy:  tensor(0.8438)
# 0.4102739095687866
# Batch Training Accuracy:  tensor(0.8594)
# 0.42067867517471313
# Batch Training Accuracy:  tensor(0.8438)
# 0.30819371342658997
# Batch Training Accuracy:  tensor(0.8906)
# 0.39297667145729065
# Batch Training Accuracy:  tensor(0.8281)
# 0.5128839612007141
# Batch Training Accuracy:  tensor(0.7500)
# 0.5455400943756104
# Batch Training Accuracy:  tensor(0.7500)
# 0.3900643587112427
# Batch Training Accuracy:  tensor(0.8594)
# 0.5639932751655579
# Batch Training Accuracy:  tensor(0.8438)
# 0.4058521091938019
# Batch Training Accuracy:  tensor(0.8125)
# 0.5997027158737183
# Batch Training Accuracy:  tensor(0.7656)
# 0.4989106357097626
# Batch Training Accuracy:  tensor(0.8281)
# 0.723869800567627
# Batch Training Accuracy:  tensor(0.7188)
# 0.4748661518096924
# Batch Training Accuracy:  tensor(0.8281)
# 0.515961766242981
# Batch Training Accuracy:  tensor(0.7969)
# 0.4674806296825409
# Batch Training Accuracy:  tensor(0.8281)
# 0.41442394256591797
# Batch Training Accuracy:  tensor(0.8125)
# 0.40862247347831726
# Batch Training Accuracy:  tensor(0.8281)
# 0.41092193126678467
# Batch Training Accuracy:  tensor(0.7812)
# 0.597899854183197
# Batch Training Accuracy:  tensor(0.7969)
# 0.7608060240745544
# Batch Training Accuracy:  tensor(0.7500)
# 0.6405491828918457
# Batch Training Accuracy:  tensor(0.7969)
# 0.46292734146118164
# Batch Training Accuracy:  tensor(0.8438)
# 0.5360023975372314
# Batch Training Accuracy:  tensor(0.8125)
# 0.44249194860458374
# Batch Training Accuracy:  tensor(0.8594)
# 0.2932141423225403
# Batch Training Accuracy:  tensor(0.8750)
# 0.44098636507987976
# Batch Training Accuracy:  tensor(0.8281)
# 0.3232037425041199
# Batch Training Accuracy:  tensor(0.8906)
# 0.41792771220207214
# Batch Training Accuracy:  tensor(0.8750)
# 0.5609552264213562
# Batch Training Accuracy:  tensor(0.8438)
# 0.36657047271728516
# Batch Training Accuracy:  tensor(0.8750)
# 0.511414110660553
# Batch Training Accuracy:  tensor(0.8125)
# 0.5022551417350769
# Batch Training Accuracy:  tensor(0.7812)
# 0.3679681122303009
# Batch Training Accuracy:  tensor(0.8906)
# 0.37165871262550354
# Batch Training Accuracy:  tensor(0.8594)
# 0.30831629037857056
# Batch Training Accuracy:  tensor(0.8438)
# 0.4708968997001648
# Batch Training Accuracy:  tensor(0.8281)
# 0.5850921869277954
# Batch Training Accuracy:  tensor(0.7969)
# 0.5526026487350464
# Batch Training Accuracy:  tensor(0.7812)
# 0.4272180199623108
# Batch Training Accuracy:  tensor(0.8594)
# 0.5340874791145325
# Batch Training Accuracy:  tensor(0.8125)
# 0.4980117976665497
# Batch Training Accuracy:  tensor(0.8438)
# 0.4792118966579437
# Batch Training Accuracy:  tensor(0.7812)
# 0.44814419746398926
# Batch Training Accuracy:  tensor(0.8438)
# 0.3506210744380951
# Batch Training Accuracy:  tensor(0.8906)
# 0.6262882351875305
# Batch Training Accuracy:  tensor(0.7656)
# 0.4459031820297241
# Batch Training Accuracy:  tensor(0.8125)
# 0.4938928782939911
# Batch Training Accuracy:  tensor(0.8438)
# 0.5765711069107056
# Batch Training Accuracy:  tensor(0.8125)
# 0.6015726923942566
# Batch Training Accuracy:  tensor(0.7500)
# 0.3891983926296234
# Batch Training Accuracy:  tensor(0.8750)
# 0.3584155738353729
# Batch Training Accuracy:  tensor(0.8281)
# 0.585565447807312
# Batch Training Accuracy:  tensor(0.7656)
# 0.3658328652381897
# Batch Training Accuracy:  tensor(0.8594)
# 0.48606523871421814
# Batch Training Accuracy:  tensor(0.8438)
# 0.4381004273891449
# Batch Training Accuracy:  tensor(0.8594)
# 0.5230361819267273
# Batch Training Accuracy:  tensor(0.7969)
# 0.5667017102241516
# Batch Training Accuracy:  tensor(0.7344)
# 0.5832074284553528
# Batch Training Accuracy:  tensor(0.7812)
# 0.4621601998806
# Batch Training Accuracy:  tensor(0.7969)
# 0.46190541982650757
# Batch Training Accuracy:  tensor(0.8125)
# 0.3820025622844696
# Batch Training Accuracy:  tensor(0.8594)
# 0.568279504776001
# Batch Training Accuracy:  tensor(0.7500)
# 0.3346427083015442
# Batch Training Accuracy:  tensor(0.8750)
# 0.5370694994926453
# Batch Training Accuracy:  tensor(0.8125)
# 0.4255271553993225
# Batch Training Accuracy:  tensor(0.8125)
# 0.372400164604187
# Batch Training Accuracy:  tensor(0.8594)
# 0.5522297620773315
# Batch Training Accuracy:  tensor(0.8438)
# 0.35255166888237
# Batch Training Accuracy:  tensor(0.8594)
# 0.4303232729434967
# Batch Training Accuracy:  tensor(0.8594)
# 0.5097396373748779
# Batch Training Accuracy:  tensor(0.8125)
# 0.3570760190486908
# Batch Training Accuracy:  tensor(0.8750)
# 0.2501806616783142
# Batch Training Accuracy:  tensor(0.9062)
# 0.27261438965797424
# Batch Training Accuracy:  tensor(0.9062)
# 0.6203224062919617
# Batch Training Accuracy:  tensor(0.8125)
# 0.5236461758613586
# Batch Training Accuracy:  tensor(0.7812)
# 0.3925752341747284
# Batch Training Accuracy:  tensor(0.8750)
# 0.3805840015411377
# Batch Training Accuracy:  tensor(0.8906)
# 0.4216621220111847
# Batch Training Accuracy:  tensor(0.8438)
# 0.6228175163269043
# Batch Training Accuracy:  tensor(0.7812)
# 0.31841617822647095
# Batch Training Accuracy:  tensor(0.8594)
# 0.565635621547699
# Batch Training Accuracy:  tensor(0.7812)
# 0.7053123712539673
# Batch Training Accuracy:  tensor(0.7500)
# 0.5543965697288513
# Batch Training Accuracy:  tensor(0.7969)
# 0.3129599690437317
# Batch Training Accuracy:  tensor(0.8906)
# 0.361233115196228
# Batch Training Accuracy:  tensor(0.7969)
# 0.6626945734024048
# Batch Training Accuracy:  tensor(0.7500)
# 0.262981653213501
# Batch Training Accuracy:  tensor(0.9375)
# 0.31592151522636414
# Batch Training Accuracy:  tensor(0.8906)
# 0.36542418599128723
# Batch Training Accuracy:  tensor(0.8906)
# 0.3672230541706085
# Batch Training Accuracy:  tensor(0.8750)
# 0.3374203145503998
# Batch Training Accuracy:  tensor(0.8594)
# 0.5027031302452087
# Batch Training Accuracy:  tensor(0.8438)
# 0.4760768711566925
# Batch Training Accuracy:  tensor(0.7812)
# 0.4161909818649292
# Batch Training Accuracy:  tensor(0.8438)
# 0.4211835563182831
# Batch Training Accuracy:  tensor(0.8594)
# 0.5383034944534302
# Batch Training Accuracy:  tensor(0.7812)
# 0.601757824420929
# Batch Training Accuracy:  tensor(0.7812)
# 0.34021058678627014
# Batch Training Accuracy:  tensor(0.8594)
# 0.4019644260406494
# Batch Training Accuracy:  tensor(0.8281)
# 0.46785151958465576
# Batch Training Accuracy:  tensor(0.8594)
# 0.6932324171066284
# Batch Training Accuracy:  tensor(0.7812)
# 0.4098300635814667
# Batch Training Accuracy:  tensor(0.8906)
# 0.355976402759552
# Batch Training Accuracy:  tensor(0.8906)
# 0.6045999526977539
# Batch Training Accuracy:  tensor(0.7500)
# 0.45141637325286865
# Batch Training Accuracy:  tensor(0.8438)
# 0.48459118604660034
# Batch Training Accuracy:  tensor(0.8594)
# 0.4967852532863617
# Batch Training Accuracy:  tensor(0.7812)
# 0.5480320453643799
# Batch Training Accuracy:  tensor(0.8125)
# 0.4445996582508087
# Batch Training Accuracy:  tensor(0.7969)
# 0.683436930179596
# Batch Training Accuracy:  tensor(0.7812)
# 0.5193630456924438
# Batch Training Accuracy:  tensor(0.7969)
# 0.325788676738739
# Batch Training Accuracy:  tensor(0.8750)
# 0.529085636138916
# Batch Training Accuracy:  tensor(0.7969)
# 0.47490668296813965
# Batch Training Accuracy:  tensor(0.8594)
# 0.4709218740463257
# Batch Training Accuracy:  tensor(0.7969)
# 0.41730746626853943
# Batch Training Accuracy:  tensor(0.7969)
# 0.49272996187210083
# Batch Training Accuracy:  tensor(0.8125)
# 0.4916752874851227
# Batch Training Accuracy:  tensor(0.7812)
# 0.5734015107154846
# Batch Training Accuracy:  tensor(0.7500)
# 0.36258965730667114
# Batch Training Accuracy:  tensor(0.8906)
# 0.48938408493995667
# Batch Training Accuracy:  tensor(0.8438)
# 0.42933252453804016
# Batch Training Accuracy:  tensor(0.8594)
# 0.5471093654632568
# Batch Training Accuracy:  tensor(0.8125)
# 0.3396419584751129
# Batch Training Accuracy:  tensor(0.8906)
# 0.2721775770187378
# Batch Training Accuracy:  tensor(0.8906)
# 0.4287336766719818
# Batch Training Accuracy:  tensor(0.7969)
# 0.4224644601345062
# Batch Training Accuracy:  tensor(0.8750)
# 0.43614932894706726
# Batch Training Accuracy:  tensor(0.9062)
# 0.5529924035072327
# Batch Training Accuracy:  tensor(0.7969)
# 0.39050620794296265
# Batch Training Accuracy:  tensor(0.8594)
# 0.5988041162490845
# Batch Training Accuracy:  tensor(0.7188)
# 0.6155772805213928
# Batch Training Accuracy:  tensor(0.7344)
# 0.3173808753490448
# Batch Training Accuracy:  tensor(0.9062)
# 0.4876304566860199
# Batch Training Accuracy:  tensor(0.8281)
# 0.332434743642807
# Batch Training Accuracy:  tensor(0.8906)
# 0.4406971335411072
# Batch Training Accuracy:  tensor(0.7656)
# 0.41031506657600403
# Batch Training Accuracy:  tensor(0.8281)
# 0.5711698532104492
# Batch Training Accuracy:  tensor(0.7969)
# 0.37301889061927795
# Batch Training Accuracy:  tensor(0.8906)
# 0.5321594476699829
# Batch Training Accuracy:  tensor(0.8281)
# 0.33636826276779175
# Batch Training Accuracy:  tensor(0.8750)
# 0.4312743544578552
# Batch Training Accuracy:  tensor(0.8594)
# 0.46479031443595886
# Batch Training Accuracy:  tensor(0.7812)
# 0.33312398195266724
# Batch Training Accuracy:  tensor(0.9062)
# 0.5149880051612854
# Batch Training Accuracy:  tensor(0.8125)
# 0.23695391416549683
# Batch Training Accuracy:  tensor(0.8750)
# 0.4806033670902252
# Batch Training Accuracy:  tensor(0.8125)
# 0.46181920170783997
# Batch Training Accuracy:  tensor(0.8125)
# 0.6578286290168762
# Batch Training Accuracy:  tensor(0.7969)
# 0.3034840226173401
# Batch Training Accuracy:  tensor(0.9531)
# 0.43778499960899353
# Batch Training Accuracy:  tensor(0.8125)
# 0.3853280544281006
# Batch Training Accuracy:  tensor(0.9062)
# 0.3950844705104828
# Batch Training Accuracy:  tensor(0.8125)
# 0.4324853718280792
# Batch Training Accuracy:  tensor(0.8281)
# 0.6477382183074951
# Batch Training Accuracy:  tensor(0.7812)
# 0.5036739110946655
# Batch Training Accuracy:  tensor(0.8594)
# 0.3136714696884155
# Batch Training Accuracy:  tensor(0.9219)
# 0.4465789794921875
# Batch Training Accuracy:  tensor(0.8281)
# 0.515383780002594
# Batch Training Accuracy:  tensor(0.7812)
# 0.35224002599716187
# Batch Training Accuracy:  tensor(0.8906)
# 0.5609958171844482
# Batch Training Accuracy:  tensor(0.7969)
# 0.5777578949928284
# Batch Training Accuracy:  tensor(0.8125)
# 0.4095994830131531
# Batch Training Accuracy:  tensor(0.8750)
# 0.42840784788131714
# Batch Training Accuracy:  tensor(0.8750)
# 0.510415256023407
# Batch Training Accuracy:  tensor(0.7656)
# 0.49799972772598267
# Batch Training Accuracy:  tensor(0.8594)
# 0.3821341097354889
# Batch Training Accuracy:  tensor(0.8438)
# 0.38466548919677734
# Batch Training Accuracy:  tensor(0.8906)
# 0.5216342210769653
# Batch Training Accuracy:  tensor(0.8594)
# 0.42784634232521057
# Batch Training Accuracy:  tensor(0.8281)
# 0.5349878668785095
# Batch Training Accuracy:  tensor(0.8281)
# 0.6087427139282227
# Batch Training Accuracy:  tensor(0.8594)
# 0.5088333487510681
# Batch Training Accuracy:  tensor(0.7969)
# 0.29613712430000305
# Batch Training Accuracy:  tensor(0.9219)
# 0.469049334526062
# Batch Training Accuracy:  tensor(0.8438)
# 0.4827565550804138
# Batch Training Accuracy:  tensor(0.8125)
# 0.5496788620948792
# Batch Training Accuracy:  tensor(0.7812)
# 0.43621426820755005
# Batch Training Accuracy:  tensor(0.8438)
# 0.46961522102355957
# Batch Training Accuracy:  tensor(0.8438)
# 0.6787514686584473
# Batch Training Accuracy:  tensor(0.7812)
# 0.4618086516857147
# Batch Training Accuracy:  tensor(0.8281)
# 0.39875954389572144
# Batch Training Accuracy:  tensor(0.8906)
# 0.4395672082901001
# Batch Training Accuracy:  tensor(0.8438)
# 0.5999506115913391
# Batch Training Accuracy:  tensor(0.7344)
# 0.4559023678302765
# Batch Training Accuracy:  tensor(0.8125)
# 0.5503872036933899
# Batch Training Accuracy:  tensor(0.8281)
# 0.30996382236480713
# Batch Training Accuracy:  tensor(0.8906)
# 0.4949236810207367
# Batch Training Accuracy:  tensor(0.8281)
# 0.4144110083580017
# Batch Training Accuracy:  tensor(0.7969)
# 0.24506865441799164
# Batch Training Accuracy:  tensor(0.9219)
# 0.30344244837760925
# Batch Training Accuracy:  tensor(0.9062)
# 0.44438838958740234
# Batch Training Accuracy:  tensor(0.8594)
# 0.4089343845844269
# Batch Training Accuracy:  tensor(0.8438)
# 0.4496094584465027
# Batch Training Accuracy:  tensor(0.8125)
# 0.30578017234802246
# Batch Training Accuracy:  tensor(0.8750)
# 0.7432253956794739
# Batch Training Accuracy:  tensor(0.8281)
# 0.3535393178462982
# Batch Training Accuracy:  tensor(0.8594)
# 0.23773342370986938
# Batch Training Accuracy:  tensor(0.9375)
# 0.41004085540771484
# Batch Training Accuracy:  tensor(0.8125)
# 0.396882563829422
# Batch Training Accuracy:  tensor(0.8438)
# 0.6659024953842163
# Batch Training Accuracy:  tensor(0.7812)
# 0.44894492626190186
# Batch Training Accuracy:  tensor(0.8594)
# 0.4309042990207672
# Batch Training Accuracy:  tensor(0.8750)
# 0.5618560314178467
# Batch Training Accuracy:  tensor(0.7500)
# 0.5720127820968628
# Batch Training Accuracy:  tensor(0.8125)
# 0.3803674876689911
# Batch Training Accuracy:  tensor(0.8750)
# 0.48194071650505066
# Batch Training Accuracy:  tensor(0.7969)
# 0.4415515065193176
# Batch Training Accuracy:  tensor(0.8281)
# 0.426978200674057
# Batch Training Accuracy:  tensor(0.8750)
# 0.620047390460968
# Batch Training Accuracy:  tensor(0.8594)
# 0.4333164095878601
# Batch Training Accuracy:  tensor(0.8438)
# 0.3724517822265625
# Batch Training Accuracy:  tensor(0.8906)
# 0.3138101100921631
# Batch Training Accuracy:  tensor(0.8750)
# 0.2552488446235657
# Batch Training Accuracy:  tensor(0.9062)
# 0.3959432542324066
# Batch Training Accuracy:  tensor(0.8438)
# 0.45342668890953064
# Batch Training Accuracy:  tensor(0.8125)
# 0.3841240704059601
# Batch Training Accuracy:  tensor(0.8438)
# 0.4998282492160797
# Batch Training Accuracy:  tensor(0.8438)
# 0.5511192679405212
# Batch Training Accuracy:  tensor(0.8281)
# 0.4164994955062866
# Batch Training Accuracy:  tensor(0.8281)
# 0.26349326968193054
# Batch Training Accuracy:  tensor(0.9062)
# 0.44156384468078613
# Batch Training Accuracy:  tensor(0.8438)
# 0.5048604011535645
# Batch Training Accuracy:  tensor(0.7812)
# 0.3176468014717102
# Batch Training Accuracy:  tensor(0.9062)
# 0.4341556429862976
# Batch Training Accuracy:  tensor(0.8281)
# 0.5236355662345886
# Batch Training Accuracy:  tensor(0.7812)
# 0.43404316902160645
# Batch Training Accuracy:  tensor(0.8594)
# 0.33756357431411743
# Batch Training Accuracy:  tensor(0.8438)
# 0.4512399137020111
# Batch Training Accuracy:  tensor(0.9062)
# 0.4432111978530884
# Batch Training Accuracy:  tensor(0.8438)
# 0.4889759421348572
# Batch Training Accuracy:  tensor(0.8125)
# 0.455434650182724
# Batch Training Accuracy:  tensor(0.8125)
# 0.26921722292900085
# Batch Training Accuracy:  tensor(0.9375)
# 0.3635159432888031
# Batch Training Accuracy:  tensor(0.8438)
# 0.5423429608345032
# Batch Training Accuracy:  tensor(0.8438)
# 0.6550648212432861
# Batch Training Accuracy:  tensor(0.7969)
# 0.6342869997024536
# Batch Training Accuracy:  tensor(0.7812)
# 0.42561933398246765
# Batch Training Accuracy:  tensor(0.8281)
# 0.3312869966030121
# Batch Training Accuracy:  tensor(0.8750)
# 0.4471120238304138
# Batch Training Accuracy:  tensor(0.8125)
# 0.456969678401947
# Batch Training Accuracy:  tensor(0.7812)
# 0.5837671756744385
# Batch Training Accuracy:  tensor(0.8438)
# 0.5592911839485168
# Batch Training Accuracy:  tensor(0.8438)
# 0.5455071926116943
# Batch Training Accuracy:  tensor(0.7812)
# 0.3739069700241089
# Batch Training Accuracy:  tensor(0.8750)
# 0.4067958891391754
# Batch Training Accuracy:  tensor(0.8906)
# 0.42751216888427734
# Batch Training Accuracy:  tensor(0.8438)
# 0.493265300989151
# Batch Training Accuracy:  tensor(0.7656)
# 0.3728899657726288
# Batch Training Accuracy:  tensor(0.8594)
# 0.35697197914123535
# Batch Training Accuracy:  tensor(0.8906)
# 0.6275287866592407
# Batch Training Accuracy:  tensor(0.8125)
# 0.4937441051006317
# Batch Training Accuracy:  tensor(0.8438)
# 0.38563525676727295
# Batch Training Accuracy:  tensor(0.8125)
# 0.4938226044178009
# Batch Training Accuracy:  tensor(0.8281)
# 0.3522970378398895
# Batch Training Accuracy:  tensor(0.9062)
# 0.38872718811035156
# Batch Training Accuracy:  tensor(0.8438)
# 0.6206284761428833
# Batch Training Accuracy:  tensor(0.7812)
# 0.35392749309539795
# Batch Training Accuracy:  tensor(0.8906)
# 0.4085562825202942
# Batch Training Accuracy:  tensor(0.8438)
# 0.4209499955177307
# Batch Training Accuracy:  tensor(0.8594)
# 0.5150507092475891
# Batch Training Accuracy:  tensor(0.7969)
# 0.45703551173210144
# Batch Training Accuracy:  tensor(0.8594)
# 0.5695503950119019
# Batch Training Accuracy:  tensor(0.7969)
# 0.4969792664051056
# Batch Training Accuracy:  tensor(0.8594)
# 0.4501538872718811
# Batch Training Accuracy:  tensor(0.8750)
# 0.6120479106903076
# Batch Training Accuracy:  tensor(0.7812)
# 0.4998228847980499
# Batch Training Accuracy:  tensor(0.8750)
# 0.4481908082962036
# Batch Training Accuracy:  tensor(0.8281)
# 0.45623815059661865
# Batch Training Accuracy:  tensor(0.8750)
# 0.3866347074508667
# Batch Training Accuracy:  tensor(0.8594)
# 0.3739326298236847
# Batch Training Accuracy:  tensor(0.9062)
# 0.7125306725502014
# Batch Training Accuracy:  tensor(0.7812)
# 0.660011351108551
# Batch Training Accuracy:  tensor(0.7656)
# 0.34033891558647156
# Batch Training Accuracy:  tensor(0.8438)
# 0.4744702875614166
# Batch Training Accuracy:  tensor(0.7969)
# 0.4340727627277374
# Batch Training Accuracy:  tensor(0.8594)
# 0.5283599495887756
# Batch Training Accuracy:  tensor(0.8281)
# 0.3779955506324768
# Batch Training Accuracy:  tensor(0.8750)
# 0.7731927633285522
# Batch Training Accuracy:  tensor(0.6875)
# 0.33570656180381775
# Batch Training Accuracy:  tensor(0.8906)
# 0.45875707268714905
# Batch Training Accuracy:  tensor(0.8125)
# 0.38170987367630005
# Batch Training Accuracy:  tensor(0.8594)
# 0.3838733434677124
# Batch Training Accuracy:  tensor(0.8125)
# 0.46121057868003845
# Batch Training Accuracy:  tensor(0.8125)
# 0.3367265462875366
# Batch Training Accuracy:  tensor(0.8906)
# 0.5247206091880798
# Batch Training Accuracy:  tensor(0.8125)
# 0.4565342366695404
# Batch Training Accuracy:  tensor(0.8125)
# 0.3636453449726105
# Batch Training Accuracy:  tensor(0.8438)
# 0.2565738558769226
# Batch Training Accuracy:  tensor(0.8906)
# 0.5314351320266724
# Batch Training Accuracy:  tensor(0.7656)
# 0.6844556331634521
# Batch Training Accuracy:  tensor(0.7656)
# 0.4904845952987671
# Batch Training Accuracy:  tensor(0.8438)
# 0.5871649384498596
# Batch Training Accuracy:  tensor(0.7812)
# 0.4347829520702362
# Batch Training Accuracy:  tensor(0.8281)
# 0.3384445011615753
# Batch Training Accuracy:  tensor(0.8594)
# 0.3668903112411499
# Batch Training Accuracy:  tensor(0.8438)
# 0.5007102489471436
# Batch Training Accuracy:  tensor(0.8125)
# 0.41836827993392944
# Batch Training Accuracy:  tensor(0.8281)
# 0.3930422067642212
# Batch Training Accuracy:  tensor(0.8438)
# 0.5736256241798401
# Batch Training Accuracy:  tensor(0.8594)
# 0.5026581287384033
# Batch Training Accuracy:  tensor(0.8594)
# 0.3906710743904114
# Batch Training Accuracy:  tensor(0.8438)
# 0.4353770315647125
# Batch Training Accuracy:  tensor(0.8281)
# 0.42073825001716614
# Batch Training Accuracy:  tensor(0.8438)
# 0.4774111211299896
# Batch Training Accuracy:  tensor(0.8594)
# 0.37345486879348755
# Batch Training Accuracy:  tensor(0.8594)
# 0.4058118462562561
# Batch Training Accuracy:  tensor(0.9062)
# 0.48983925580978394
# Batch Training Accuracy:  tensor(0.8438)
# 0.7021106481552124
# Batch Training Accuracy:  tensor(0.7969)
# 0.35373950004577637
# Batch Training Accuracy:  tensor(0.8906)
# 0.4125351905822754
# Batch Training Accuracy:  tensor(0.8594)
# 0.5180447697639465
# Batch Training Accuracy:  tensor(0.7812)
# 0.4017695486545563
# Batch Training Accuracy:  tensor(0.8594)
# 0.2753213942050934
# Batch Training Accuracy:  tensor(0.8906)
# 0.36260631680488586
# Batch Training Accuracy:  tensor(0.8750)
# 0.4593178927898407
# Batch Training Accuracy:  tensor(0.8125)
# 0.5584982633590698
# Batch Training Accuracy:  tensor(0.8281)
# 0.4629517197608948
# Batch Training Accuracy:  tensor(0.7812)
# 0.3341570496559143
# Batch Training Accuracy:  tensor(0.8438)
# 0.24581070244312286
# Batch Training Accuracy:  tensor(0.9062)
# 0.37638720870018005
# Batch Training Accuracy:  tensor(0.8594)
# 0.41180381178855896
# Batch Training Accuracy:  tensor(0.8281)
# 0.3903631865978241
# Batch Training Accuracy:  tensor(0.8438)
# 0.574580729007721
# Batch Training Accuracy:  tensor(0.7812)
# 0.6134753823280334
# Batch Training Accuracy:  tensor(0.8594)
# 0.36343276500701904
# Batch Training Accuracy:  tensor(0.8594)
# 0.4357640743255615
# Batch Training Accuracy:  tensor(0.9062)
# 0.38360777497291565
# Batch Training Accuracy:  tensor(0.8594)
# 0.42082536220550537
# Batch Training Accuracy:  tensor(0.8438)
# 0.6174653768539429
# Batch Training Accuracy:  tensor(0.6875)
# 0.32935741543769836
# Batch Training Accuracy:  tensor(0.8438)
# 0.532257616519928
# Batch Training Accuracy:  tensor(0.7812)
# 0.40241050720214844
# Batch Training Accuracy:  tensor(0.8125)
# 0.47419247031211853
# Batch Training Accuracy:  tensor(0.8281)
# 0.3198251724243164
# Batch Training Accuracy:  tensor(0.8906)
# 0.585423469543457
# Batch Training Accuracy:  tensor(0.7969)
# 0.4434061348438263
# Batch Training Accuracy:  tensor(0.8281)
# 0.2978184223175049
# Batch Training Accuracy:  tensor(0.9219)
# 0.39322903752326965
# Batch Training Accuracy:  tensor(0.8281)
# 0.40143850445747375
# Batch Training Accuracy:  tensor(0.8906)
# 0.3109699785709381
# Batch Training Accuracy:  tensor(0.8594)
# 0.34290358424186707
# Batch Training Accuracy:  tensor(0.8750)
# 0.3586055040359497
# Batch Training Accuracy:  tensor(0.8750)
# 0.3154432773590088
# Batch Training Accuracy:  tensor(0.8906)
# 0.4354202449321747
# Batch Training Accuracy:  tensor(0.8594)
# 0.4081280827522278
# Batch Training Accuracy:  tensor(0.8438)
# 0.5063836574554443
# Batch Training Accuracy:  tensor(0.8125)
# 0.4083540141582489
# Batch Training Accuracy:  tensor(0.8281)
# 0.4051278233528137
# Batch Training Accuracy:  tensor(0.8438)
# 0.4045650362968445
# Batch Training Accuracy:  tensor(0.8438)
# 0.36771446466445923
# Batch Training Accuracy:  tensor(0.8750)
# 0.40406689047813416
# Batch Training Accuracy:  tensor(0.8594)
# 0.32649335265159607
# Batch Training Accuracy:  tensor(0.8594)
# 0.3635624647140503
# Batch Training Accuracy:  tensor(0.8438)
# 0.3645983636379242
# Batch Training Accuracy:  tensor(0.8438)
# 0.4480533301830292
# Batch Training Accuracy:  tensor(0.7969)
# 0.3283443748950958
# Batch Training Accuracy:  tensor(0.8281)
# 0.3068171441555023
# Batch Training Accuracy:  tensor(0.8438)
# 0.355095237493515
# Batch Training Accuracy:  tensor(0.8594)
# 0.4054310917854309
# Batch Training Accuracy:  tensor(0.8594)
# 0.5534207224845886
# Batch Training Accuracy:  tensor(0.8125)
# 0.4072868525981903
# Batch Training Accuracy:  tensor(0.8750)
# 0.37097060680389404
# Batch Training Accuracy:  tensor(0.8125)
# 0.45968568325042725
# Batch Training Accuracy:  tensor(0.7969)
# 0.40942898392677307
# Batch Training Accuracy:  tensor(0.8438)
# 0.4783518314361572
# Batch Training Accuracy:  tensor(0.8281)
# 0.259219765663147
# Batch Training Accuracy:  tensor(0.8750)
# 0.5866106152534485
# Batch Training Accuracy:  tensor(0.7969)
# 0.34261178970336914
# Batch Training Accuracy:  tensor(0.8906)
# 0.5269407033920288
# Batch Training Accuracy:  tensor(0.8438)
# 0.40075668692588806
# Batch Training Accuracy:  tensor(0.7812)
# 0.39673441648483276
# Batch Training Accuracy:  tensor(0.8750)
# 0.5225040912628174
# Batch Training Accuracy:  tensor(0.7656)
# 0.2363574504852295
# Batch Training Accuracy:  tensor(0.9688)
# 0.22338905930519104
# Batch Training Accuracy:  tensor(0.9531)
# 0.5066702961921692
# ...
# Batch Training Accuracy:  tensor(0.8750)
# 0.35746926069259644
# Batch Training Accuracy:  tensor(0.8438)
# 0.34347325563430786
# Batch Training Accuracy:  tensor(0.8594)
# 0.2705480754375458
# Batch Training Accuracy:  tensor(0.8906)
# 0.26322516798973083
# Batch Training Accuracy:  tensor(0.9062)
# 0.3336525857448578
# Batch Training Accuracy:  tensor(0.8438)
# 0.4012032151222229
# Batch Training Accuracy:  tensor(0.8281)
# 0.3412625193595886
# Batch Training Accuracy:  tensor(0.8750)
# 0.24802157282829285
# Batch Training Accuracy:  tensor(0.9375)
# 0.33755525946617126
# Batch Training Accuracy:  tensor(0.8750)
# 0.47856491804122925
# Batch Training Accuracy:  tensor(0.7656)
# 0.2637997567653656
# Batch Training Accuracy:  tensor(0.9375)
# 0.42772069573402405
# Batch Training Accuracy:  tensor(0.8594)
# 0.23759931325912476
# Batch Training Accuracy:  tensor(0.9062)
# 0.3963643014431
# Batch Training Accuracy:  tensor(0.8281)
# 0.3178451955318451
# Batch Training Accuracy:  tensor(0.8750)
# 0.3604664206504822
# Batch Training Accuracy:  tensor(0.8125)
# 0.3808365762233734
# Batch Training Accuracy:  tensor(0.8438)
# 0.35887444019317627
# Batch Training Accuracy:  tensor(0.9062)
# 0.3566860556602478
# Batch Training Accuracy:  tensor(0.8750)
# 0.365726113319397
# Batch Training Accuracy:  tensor(0.8594)
# 0.41419336199760437
# Batch Training Accuracy:  tensor(0.8438)
# 0.2166896015405655
# Batch Training Accuracy:  tensor(0.8906)
# 0.42556825280189514
# Batch Training Accuracy:  tensor(0.8594)
# 0.34912341833114624
# Batch Training Accuracy:  tensor(0.8281)
# 0.2407677173614502
# Batch Training Accuracy:  tensor(0.9062)
# 0.3057863414287567
# Batch Training Accuracy:  tensor(0.9062)
# 0.39001598954200745
# Batch Training Accuracy:  tensor(0.8906)
# 0.24627146124839783
# Batch Training Accuracy:  tensor(0.9062)
# 0.4858764708042145
# Batch Training Accuracy:  tensor(0.8438)
# 0.20871959626674652
# Batch Training Accuracy:  tensor(0.8906)
# 0.38354387879371643
# Batch Training Accuracy:  tensor(0.8438)
# 0.2565506100654602
# Batch Training Accuracy:  tensor(0.9062)
# 0.4510713517665863
# Batch Training Accuracy:  tensor(0.8438)
# 0.33352258801460266
# Batch Training Accuracy:  tensor(0.8906)
# 0.3335969150066376
# Batch Training Accuracy:  tensor(0.8125)
# 0.2359941452741623
# Batch Training Accuracy:  tensor(0.9062)
# 0.3123437464237213
# Batch Training Accuracy:  tensor(0.8906)
# 0.2655651867389679
# Batch Training Accuracy:  tensor(0.9219)
# 0.3551602363586426
# Batch Training Accuracy:  tensor(0.8750)
# 0.3263222873210907
# Batch Training Accuracy:  tensor(0.8594)
# 0.19663703441619873
# Batch Training Accuracy:  tensor(0.9219)
# 0.5597987174987793
# Batch Training Accuracy:  tensor(0.7969)
# 0.22393831610679626
# Batch Training Accuracy:  tensor(0.9375)
# 0.2571411728858948
# Batch Training Accuracy:  tensor(0.9219)
# 0.33467423915863037
# Batch Training Accuracy:  tensor(0.8750)
# 0.20948514342308044
# Batch Training Accuracy:  tensor(0.9062)
# 0.20883576571941376
# Batch Training Accuracy:  tensor(0.9219)
# 0.265137255191803
# Batch Training Accuracy:  tensor(0.8906)
# 0.4563581943511963
# Batch Training Accuracy:  tensor(0.8750)
# 0.19403094053268433
# Batch Training Accuracy:  tensor(0.9375)
# 0.22864240407943726
# Batch Training Accuracy:  tensor(0.9375)
# 0.2759254574775696
# Batch Training Accuracy:  tensor(0.9219)
# 0.18281258642673492
# Batch Training Accuracy:  tensor(0.9375)
# 0.2816869914531708
# Batch Training Accuracy:  tensor(0.8750)
# 0.2479047179222107
# Batch Training Accuracy:  tensor(0.8906)
# 0.3001296818256378
# Batch Training Accuracy:  tensor(0.8594)
# 0.4505804479122162
# Batch Training Accuracy:  tensor(0.8281)
# 0.24803254008293152
# Batch Training Accuracy:  tensor(0.9375)
# 0.45448771119117737
# Batch Training Accuracy:  tensor(0.7969)
# 0.2416602224111557
# Batch Training Accuracy:  tensor(0.9062)
# 0.2931804656982422
# Batch Training Accuracy:  tensor(0.8750)
# 0.40245845913887024
# Batch Training Accuracy:  tensor(0.7969)
# 0.3689829111099243
# Batch Training Accuracy:  tensor(0.8750)
# 0.28045645356178284
# Batch Training Accuracy:  tensor(0.8906)
# 0.26299452781677246
# Batch Training Accuracy:  tensor(0.8906)
# 0.25157928466796875
# Batch Training Accuracy:  tensor(0.8750)
# 0.2324797362089157
# Batch Training Accuracy:  tensor(0.9062)
# 0.3913700580596924
# Batch Training Accuracy:  tensor(0.8125)
# 0.3582327663898468
# Batch Training Accuracy:  tensor(0.9062)
# 0.26432013511657715
# Batch Training Accuracy:  tensor(0.8594)
# 0.3373938202857971
# Batch Training Accuracy:  tensor(0.9062)
# 0.2621951997280121
# Batch Training Accuracy:  tensor(0.9062)
# 0.1621048003435135
# Batch Training Accuracy:  tensor(0.9688)
# 0.32767394185066223
# Batch Training Accuracy:  tensor(0.8438)
# 0.4511682987213135
# Batch Training Accuracy:  tensor(0.8750)
# 0.5029207468032837
# Batch Training Accuracy:  tensor(0.7812)
# 0.3940355181694031
# Batch Training Accuracy:  tensor(0.8594)
# 0.5021485090255737
# Batch Training Accuracy:  tensor(0.7969)
# 0.2624589800834656
# Batch Training Accuracy:  tensor(0.8906)
# 0.27980589866638184
# Batch Training Accuracy:  tensor(0.9062)
# 0.6297240257263184
# Batch Training Accuracy:  tensor(0.7656)
# 0.26927900314331055
# Batch Training Accuracy:  tensor(0.9062)
# 0.2839028239250183
# Batch Training Accuracy:  tensor(0.9062)
# 0.34141308069229126
# Batch Training Accuracy:  tensor(0.8594)
# 0.21333321928977966
# Batch Training Accuracy:  tensor(0.9375)
# 0.44649559259414673
# Batch Training Accuracy:  tensor(0.8125)
# 0.5083898901939392
# Batch Training Accuracy:  tensor(0.8438)
# 0.2592333257198334
# Batch Training Accuracy:  tensor(0.8906)
# 0.2884191870689392
# Batch Training Accuracy:  tensor(0.9219)
# 0.27385303378105164
# Batch Training Accuracy:  tensor(0.9062)
# 0.2965107262134552
# Batch Training Accuracy:  tensor(0.9062)
# 0.25356540083885193
# Batch Training Accuracy:  tensor(0.8750)
# 0.4150567054748535
# Batch Training Accuracy:  tensor(0.8594)
# 0.38989368081092834
# Batch Training Accuracy:  tensor(0.8906)
# 0.31519007682800293
# Batch Training Accuracy:  tensor(0.8906)
# 0.41973137855529785
# Batch Training Accuracy:  tensor(0.8281)
# 0.2435070276260376
# Batch Training Accuracy:  tensor(0.9219)
# 0.5211055874824524
# Batch Training Accuracy:  tensor(0.7969)
# 0.30242106318473816
# Batch Training Accuracy:  tensor(0.8594)
# 0.27539411187171936
# Batch Training Accuracy:  tensor(0.8906)
# 0.23667410016059875
# Batch Training Accuracy:  tensor(0.9062)
# 0.3330579996109009
# Batch Training Accuracy:  tensor(0.8438)
# 0.2655906677246094
# Batch Training Accuracy:  tensor(0.8906)
# 0.346525639295578
# Batch Training Accuracy:  tensor(0.8906)
# 0.3030540645122528
# Batch Training Accuracy:  tensor(0.8594)
# 0.2782666087150574
# Batch Training Accuracy:  tensor(0.8906)
# 0.27794235944747925
# Batch Training Accuracy:  tensor(0.8906)
# 0.295465350151062
# Batch Training Accuracy:  tensor(0.8906)
# 0.2493189126253128
# Batch Training Accuracy:  tensor(0.9062)
# 0.32828518748283386
# Batch Training Accuracy:  tensor(0.8906)
# 0.35684579610824585
# Batch Training Accuracy:  tensor(0.9062)
# 0.19111661612987518
# Batch Training Accuracy:  tensor(0.9375)
# 0.26755478978157043
# Batch Training Accuracy:  tensor(0.9219)
# 0.42155855894088745
# Batch Training Accuracy:  tensor(0.8438)
# 0.3233795762062073
# Batch Training Accuracy:  tensor(0.8594)
# 0.31724050641059875
# Batch Training Accuracy:  tensor(0.9062)
# 0.2842566668987274
# Batch Training Accuracy:  tensor(0.9062)
# 0.3379104733467102
# Batch Training Accuracy:  tensor(0.9062)
# 0.5097755789756775
# Batch Training Accuracy:  tensor(0.8125)
# 0.23085126280784607
# Batch Training Accuracy:  tensor(0.8906)
# 0.41520220041275024
# Batch Training Accuracy:  tensor(0.8438)
# 0.3098243772983551
# Batch Training Accuracy:  tensor(0.9062)
# 0.18859757483005524
# Batch Training Accuracy:  tensor(0.9531)
# 0.47598856687545776
# Batch Training Accuracy:  tensor(0.8594)
# 0.1820271909236908
# Batch Training Accuracy:  tensor(0.9531)
# 0.19396893680095673
# Batch Training Accuracy:  tensor(0.9375)
# 0.39601218700408936
# Batch Training Accuracy:  tensor(0.8281)
# 0.2981675863265991
# Batch Training Accuracy:  tensor(0.9062)
# 0.43246930837631226
# Batch Training Accuracy:  tensor(0.8594)
# 0.2950594127178192
# Batch Training Accuracy:  tensor(0.8750)
# 0.24105724692344666
# Batch Training Accuracy:  tensor(0.9062)
# 0.2114521861076355
# Batch Training Accuracy:  tensor(0.9062)
# 0.20285455882549286
# Batch Training Accuracy:  tensor(0.9219)
# 0.18391646444797516
# Batch Training Accuracy:  tensor(0.9375)
# 0.31809765100479126
# Batch Training Accuracy:  tensor(0.8750)
# 0.35116907954216003
# Batch Training Accuracy:  tensor(0.8438)
# 0.17521251738071442
# Batch Training Accuracy:  tensor(0.9062)
# 0.19841624796390533
# Batch Training Accuracy:  tensor(0.9219)
# 0.43978801369667053
# Batch Training Accuracy:  tensor(0.8281)
# 0.4187949001789093
# Batch Training Accuracy:  tensor(0.8594)
# 0.3256802260875702
# Batch Training Accuracy:  tensor(0.8906)
# 0.43979430198669434
# Batch Training Accuracy:  tensor(0.8125)
# 0.3654559552669525
# Batch Training Accuracy:  tensor(0.8594)
# 0.1629616767168045
# Batch Training Accuracy:  tensor(0.9219)
# 0.26298651099205017
# Batch Training Accuracy:  tensor(0.8750)
# 0.4014868438243866
# Batch Training Accuracy:  tensor(0.8594)
# 0.48325759172439575
# Batch Training Accuracy:  tensor(0.8125)
# 0.33997997641563416
# Batch Training Accuracy:  tensor(0.8594)
# 0.24805095791816711
# Batch Training Accuracy:  tensor(0.9062)
# 0.34771719574928284
# Batch Training Accuracy:  tensor(0.8906)
# 0.4176957905292511
# Batch Training Accuracy:  tensor(0.8125)
# 0.24039940536022186
# Batch Training Accuracy:  tensor(0.9219)
# 0.4920511245727539
# Batch Training Accuracy:  tensor(0.7656)
# 0.3427380919456482
# Batch Training Accuracy:  tensor(0.8906)
# 0.19996558129787445
# Batch Training Accuracy:  tensor(0.9531)
# 0.24376247823238373
# Batch Training Accuracy:  tensor(0.9375)
# 0.3225443959236145
# Batch Training Accuracy:  tensor(0.8438)
# 0.3373568058013916
# Batch Training Accuracy:  tensor(0.8906)
# 0.14973260462284088
# Batch Training Accuracy:  tensor(0.9844)
# 0.32739442586898804
# Batch Training Accuracy:  tensor(0.8594)
# 0.4162968397140503
# Batch Training Accuracy:  tensor(0.8906)
# 0.3430403769016266
# Batch Training Accuracy:  tensor(0.8750)
# 0.3311203420162201
# Batch Training Accuracy:  tensor(0.8594)
# 0.41398510336875916
# Batch Training Accuracy:  tensor(0.8750)
# 0.4498390555381775
# Batch Training Accuracy:  tensor(0.8125)
# 0.38236597180366516
# Batch Training Accuracy:  tensor(0.8438)
# 0.6489456295967102
# Batch Training Accuracy:  tensor(0.7656)
# 0.39512231945991516
# Batch Training Accuracy:  tensor(0.8750)
# 0.46225860714912415
# Batch Training Accuracy:  tensor(0.8906)
# 0.3106499910354614
# Batch Training Accuracy:  tensor(0.8594)
# 0.3100792467594147
# Batch Training Accuracy:  tensor(0.8750)
# 0.1462235301733017
# Batch Training Accuracy:  tensor(0.9531)
# 0.3974885940551758
# Batch Training Accuracy:  tensor(0.8281)
# 0.39135056734085083
# Batch Training Accuracy:  tensor(0.8906)
# 0.2736002504825592
# Batch Training Accuracy:  tensor(0.8594)
# 0.2870645821094513
# Batch Training Accuracy:  tensor(0.8594)
# 0.3594299256801605
# Batch Training Accuracy:  tensor(0.8281)
# 0.5738893151283264
# Batch Training Accuracy:  tensor(0.8906)
# 0.6268521547317505
# Batch Training Accuracy:  tensor(0.8125)
# 0.39263665676116943
# Batch Training Accuracy:  tensor(0.8438)
# 0.29879727959632874
# Batch Training Accuracy:  tensor(0.8906)
# 0.26238805055618286
# Batch Training Accuracy:  tensor(0.8906)
# 0.25701576471328735
# Batch Training Accuracy:  tensor(0.9062)
# 0.3372058570384979
# Batch Training Accuracy:  tensor(0.8594)
# 0.28325483202934265
# Batch Training Accuracy:  tensor(0.8750)
# 0.44438502192497253
# Batch Training Accuracy:  tensor(0.8281)
# 0.3253798484802246
# Batch Training Accuracy:  tensor(0.8750)
# 0.34534960985183716
# Batch Training Accuracy:  tensor(0.8594)
# 0.4037776589393616
# Batch Training Accuracy:  tensor(0.8594)
# 0.5257266759872437
# Batch Training Accuracy:  tensor(0.8281)
# 0.4149284064769745
# Batch Training Accuracy:  tensor(0.8125)
# 0.4489327073097229
# Batch Training Accuracy:  tensor(0.8281)
# 0.31360337138175964
# Batch Training Accuracy:  tensor(0.8594)
# 0.33449265360832214
# Batch Training Accuracy:  tensor(0.8438)
# 0.4090123772621155
# Batch Training Accuracy:  tensor(0.8281)
# 0.35641229152679443
# Batch Training Accuracy:  tensor(0.8438)
# 0.39462608098983765
# Batch Training Accuracy:  tensor(0.8750)
# 0.434988796710968
# Batch Training Accuracy:  tensor(0.8281)
# 0.4826837480068207
# Batch Training Accuracy:  tensor(0.7969)
# 0.305554062128067
# Batch Training Accuracy:  tensor(0.8750)
# 0.45812666416168213
# Batch Training Accuracy:  tensor(0.8281)
# 0.23418612778186798
# Batch Training Accuracy:  tensor(0.9062)
# 0.34610140323638916
# Batch Training Accuracy:  tensor(0.8594)
# 0.3102026879787445
# Batch Training Accuracy:  tensor(0.8594)
# 0.39005765318870544
# Batch Training Accuracy:  tensor(0.8750)
# 0.4435248374938965
# Batch Training Accuracy:  tensor(0.7969)
# 0.2977687120437622
# Batch Training Accuracy:  tensor(0.8750)
# 0.5223000645637512
# Batch Training Accuracy:  tensor(0.8281)
# 0.3907952308654785
# Batch Training Accuracy:  tensor(0.8438)
# 0.2716491222381592
# Batch Training Accuracy:  tensor(0.8906)
# 0.4299342632293701
# Batch Training Accuracy:  tensor(0.8594)
# 0.2698809504508972
# Batch Training Accuracy:  tensor(0.8750)
# 0.16626198589801788
# Batch Training Accuracy:  tensor(0.9531)
# 0.44570985436439514
# Batch Training Accuracy:  tensor(0.8594)
# 0.245827317237854
# Batch Training Accuracy:  tensor(0.8906)
# 0.3169327974319458
# Batch Training Accuracy:  tensor(0.9219)
# 0.322519451379776
# Batch Training Accuracy:  tensor(0.8906)
# 0.2419818788766861
# Batch Training Accuracy:  tensor(0.8906)
# 0.34080296754837036
# Batch Training Accuracy:  tensor(0.8750)
# 0.2129373848438263
# Batch Training Accuracy:  tensor(0.9531)
# 0.32396426796913147
# Batch Training Accuracy:  tensor(0.8750)
# 0.3836745023727417
# Batch Training Accuracy:  tensor(0.8594)
# 0.3003798723220825
# Batch Training Accuracy:  tensor(0.8750)
# 0.34719738364219666
# Batch Training Accuracy:  tensor(0.9219)
# 0.2370767593383789
# Batch Training Accuracy:  tensor(0.9219)
# 0.2975592315196991
# Batch Training Accuracy:  tensor(0.8438)
# 0.2853745222091675
# Batch Training Accuracy:  tensor(0.9375)
# 0.3167852759361267
# Batch Training Accuracy:  tensor(0.8594)
# 0.18028366565704346
# Batch Training Accuracy:  tensor(0.9062)
# 0.5721143484115601
# Batch Training Accuracy:  tensor(0.7969)
# 0.22966888546943665
# Batch Training Accuracy:  tensor(0.9375)
# 0.22461237013339996
# Batch Training Accuracy:  tensor(0.9062)
# 0.21857665479183197
# Batch Training Accuracy:  tensor(0.9062)
# 0.31775084137916565
# Batch Training Accuracy:  tensor(0.8438)
# 0.2584359645843506
# Batch Training Accuracy:  tensor(0.8906)
# 0.5066717863082886
# Batch Training Accuracy:  tensor(0.8438)
# 0.20238254964351654
# Batch Training Accuracy:  tensor(0.9531)
# 0.45045751333236694
# Batch Training Accuracy:  tensor(0.8594)
# 0.2617190480232239
# Batch Training Accuracy:  tensor(0.9375)
# 0.23133769631385803
# Batch Training Accuracy:  tensor(0.9219)
# 0.3374597728252411
# Batch Training Accuracy:  tensor(0.8906)
# 0.25238099694252014
# Batch Training Accuracy:  tensor(0.9219)
# 0.4252750873565674
# Batch Training Accuracy:  tensor(0.8438)
# 0.2263641208410263
# Batch Training Accuracy:  tensor(0.9219)
# 0.44415032863616943
# Batch Training Accuracy:  tensor(0.8594)
# 0.5042609572410583
# Batch Training Accuracy:  tensor(0.7969)
# 0.2063373476266861
# Batch Training Accuracy:  tensor(0.9375)
# 0.23630855977535248
# Batch Training Accuracy:  tensor(0.8750)
# 0.39393728971481323
# Batch Training Accuracy:  tensor(0.8125)
# 0.3624216914176941
# Batch Training Accuracy:  tensor(0.8594)
# 0.34570935368537903
# Batch Training Accuracy:  tensor(0.8906)
# 0.16466425359249115
# Batch Training Accuracy:  tensor(0.9531)
# 0.34540432691574097
# Batch Training Accuracy:  tensor(0.8594)
# 0.1639002412557602
# Batch Training Accuracy:  tensor(0.9375)
# 0.43238601088523865
# Batch Training Accuracy:  tensor(0.8594)
# 0.336271196603775
# Batch Training Accuracy:  tensor(0.9062)
# 0.3316541612148285
# Batch Training Accuracy:  tensor(0.8750)
# 0.24438540637493134
# Batch Training Accuracy:  tensor(0.9219)
# 0.20984767377376556
# Batch Training Accuracy:  tensor(0.9531)
# 0.15148372948169708
# Batch Training Accuracy:  tensor(0.9219)
# 0.442359983921051
# Batch Training Accuracy:  tensor(0.8281)
# 0.25928834080696106
# Batch Training Accuracy:  tensor(0.9219)
# 0.3064675033092499
# Batch Training Accuracy:  tensor(0.9062)
# 0.38125187158584595
# Batch Training Accuracy:  tensor(0.8438)

# %%
# GPT Experimentation
model = Classifier()
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

# Check for GPU availability
device = torch.device("cpu")
print("Using device:", device)

# Move model to GPU if available
model.to(device)

epochs = 20
steps = 0

train_losses, test_losses = [], []
for e in range(epochs):
    running_loss = 0
    for images, labels in trainloader:

        images,labels =images.to(device),labels.to(device)
        
        optimizer.zero_grad()
        
        log_ps = model(images)
        loss = criterion(log_ps, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
    else:
        # Validation pass
        test_loss = 0
        accuracy = 0

        # Set the model to evaluation mode
        model.eval()

        with torch.no_grad():
            for images, labels in testloader:
                images, labels = images.to(device),labels.to(device)
                log_ps = model(images)
                test_loss += criterion(log_ps, labels).item()

                ps = torch.exp(log_ps)
                top_p, top_class = ps.topk(1, dim=1)
                equals = top_class == labels.view(*top_class.shape)
                accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

        # Set the model back to training mode
        model.train()

        train_losses.append(running_loss/len(trainloader))
        test_losses.append(test_loss/len(testloader))

        print("Epoch: {}/{}.. ".format(e+1, epochs),
              "Training Loss: {:.3f}.. ".format(running_loss/len(trainloader)),
              "Validation Loss: {:.3f}.. ".format(test_loss/len(testloader)),
              "Validation Accuracy: {:.3f}".format(accuracy/len(testloader)))
# Out:
# Using device: cpu
# Epoch: 1/20..  Training Loss: 0.519..  Validation Loss: 0.468..  Validation Accuracy: 0.827
# Epoch: 2/20..  Training Loss: 0.392..  Validation Loss: 0.407..  Validation Accuracy: 0.856
# Epoch: 3/20..  Training Loss: 0.356..  Validation Loss: 0.392..  Validation Accuracy: 0.856
# Epoch: 4/20..  Training Loss: 0.334..  Validation Loss: 0.369..  Validation Accuracy: 0.869
# Epoch: 5/20..  Training Loss: 0.318..  Validation Loss: 0.366..  Validation Accuracy: 0.870
# Epoch: 6/20..  Training Loss: 0.306..  Validation Loss: 0.363..  Validation Accuracy: 0.873
# Epoch: 7/20..  Training Loss: 0.292..  Validation Loss: 0.365..  Validation Accuracy: 0.877
# Epoch: 8/20..  Training Loss: 0.287..  Validation Loss: 0.376..  Validation Accuracy: 0.870
# Epoch: 9/20..  Training Loss: 0.274..  Validation Loss: 0.390..  Validation Accuracy: 0.870
# Epoch: 10/20..  Training Loss: 0.269..  Validation Loss: 0.374..  Validation Accuracy: 0.873
# Epoch: 11/20..  Training Loss: 0.264..  Validation Loss: 0.366..  Validation Accuracy: 0.877
# Epoch: 12/20..  Training Loss: 0.258..  Validation Loss: 0.398..  Validation Accuracy: 0.879
# Epoch: 13/20..  Training Loss: 0.249..  Validation Loss: 0.355..  Validation Accuracy: 0.880
# Epoch: 14/20..  Training Loss: 0.246..  Validation Loss: 0.398..  Validation Accuracy: 0.869
# Epoch: 15/20..  Training Loss: 0.241..  Validation Loss: 0.355..  Validation Accuracy: 0.882
# Epoch: 16/20..  Training Loss: 0.232..  Validation Loss: 0.375..  Validation Accuracy: 0.881
# Epoch: 17/20..  Training Loss: 0.230..  Validation Loss: 0.385..  Validation Accuracy: 0.880
# Epoch: 18/20..  Training Loss: 0.221..  Validation Loss: 0.386..  Validation Accuracy: 0.878
# Epoch: 19/20..  Training Loss: 0.218..  Validation Loss: 0.406..  Validation Accuracy: 0.881
# Epoch: 20/20..  Training Loss: 0.214..  Validation Loss: 0.382..  Validation Accuracy: 0.884

# %%
# from torch import topk
# import numpy as np


# model = Classifier()
# criterion = nn.NLLLoss()
# optimizer = optim.Adam(model.parameters(), lr=0.003)

# epochs = 5
# steps = 0

# test_batch_loss = []

# train_losses, test_losses = [], []
# for e in range(epochs):
#     running_loss = []
#     running_accuracy = 0
#     with torch.no_grad():
#         for images, labels in testloader:
            
#             optimizer.zero_grad()
            
#             log_ps = model(images)
#             top_p,top_class = topk(log_ps,1,dim=1)
#             equals = top_class == labels.view(*top_class.shape)
#             accuracy = torch.mean(equals.type(torch.FloatTensor))
#             print(f'Batch Accuracy: {accuracy.item()*100}%')
            
            
#             loss = criterion(log_ps, labels)

            
#             running_loss.append(loss.item())
    
    
#         else:
#             ## TODO: Implement the validation pass and print out the validation accuracy
#             test_batch_loss.append(np.mean(running_loss))
#             print(f'Accuracy: {accuracy.item()*100}%')
# Out:
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 15.625%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 3.125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 20.3125%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 18.75%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 3.125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 6.25%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 21.875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 18.75%
# Batch Accuracy: 3.125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 15.625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 15.625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 3.125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 15.625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 3.125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 3.125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Accuracy: 12.5%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 18.75%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 15.625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 3.125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 3.125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 3.125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 12.5%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 12.5%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 15.625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 23.4375%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 3.125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 18.75%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 3.125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 15.625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 15.625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 15.625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 3.125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 15.625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 18.75%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 15.625%
# Batch Accuracy: 18.75%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 15.625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 3.125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 3.125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 15.625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 12.5%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 23.4375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 6.25%
# Batch Accuracy: 15.625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 3.125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 21.875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 31.25%
# Accuracy: 31.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 20.3125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 15.625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 15.625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 15.625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 3.125%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 20.3125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 15.625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 23.4375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 3.125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 15.625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 15.625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 0.0%
# Accuracy: 0.0%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 20.3125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 6.25%
# Batch Accuracy: 18.75%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 15.625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 3.125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 6.25%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 20.3125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 14.0625%
# Batch Accuracy: 1.5625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 3.125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 4.6875%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 23.4375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 6.25%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 12.5%
# Batch Accuracy: 3.125%
# Batch Accuracy: 15.625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 7.8125%
# Batch Accuracy: 9.375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 12.5%
# Batch Accuracy: 17.1875%
# Batch Accuracy: 12.5%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 9.375%
# Batch Accuracy: 6.25%
# Batch Accuracy: 12.5%
# Batch Accuracy: 9.375%
# Batch Accuracy: 15.625%
# Batch Accuracy: 10.9375%
# Batch Accuracy: 6.25%
# Accuracy: 6.25%

# %%
import numpy as np
import matplotlib.pyplot as plt

print(len(train_losses))
print(len(test_losses))


plt.plot(list(range(epochs)),train_losses,list(range(epochs)),test_losses)
plt.xlabel("Epochs")
plt.ylabel("Loss")

# lbl =

# plt.xticks(list(range(20)),labels = )
plt.show()
# Out:
# 20
# 20

# %% [markdown]
# ## Overfitting
#
# If we look at the training and validation losses as we train the network, we can see a phenomenon known as overfitting.
#
# <img src='assets/overfitting.png' width=450px>
#
# The network learns the training set better and better, resulting in lower training losses. However, it starts having problems generalizing to data outside the training set leading to the validation loss increasing. The ultimate goal of any deep learning model is to make predictions on new data, so we should strive to get the lowest validation loss possible. One option is to use the version of the model with the lowest validation loss, here the one around 8-10 training epochs. This strategy is called *early-stopping*. In practice, you'd save the model frequently as you're training then later choose the model with the lowest validation loss.
#
# The most common method to reduce overfitting (outside of early-stopping) is *dropout*, where we randomly drop input units. This forces the network to share information between weights, increasing it's ability to generalize to new data. Adding dropout in PyTorch is straightforward using the [`nn.Dropout`](https://pytorch.org/docs/stable/nn.html#torch.nn.Dropout) module.
#
# ```python
# class Classifier(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(784, 256)
#         self.fc2 = nn.Linear(256, 128)
#         self.fc3 = nn.Linear(128, 64)
#         self.fc4 = nn.Linear(64, 10)
#
#         # Dropout module with 0.2 drop probability
#         self.dropout = nn.Dropout(p=0.2)
#
#     def forward(self, x):
#         # make sure input tensor is flattened
#         x = x.view(x.shape[0], -1)
#
#         # Now with dropout
#         x = self.dropout(F.relu(self.fc1(x)))
#         x = self.dropout(F.relu(self.fc2(x)))
#         x = self.dropout(F.relu(self.fc3(x)))
#
#         # output so no dropout here
#         x = F.log_softmax(self.fc4(x), dim=1)
#
#         return x
# ```
#
# During training we want to use dropout to prevent overfitting, but during inference we want to use the entire network. So, we need to turn off dropout during validation, testing, and whenever we're using the network to make predictions. To do this, you use `model.eval()`. This sets the model to evaluation mode where the dropout probability is 0. You can turn dropout back on by setting the model to train mode with `model.train()`. In general, the pattern for the validation loop will look like this, where you turn off gradients, set the model to evaluation mode, calculate the validation loss and metric, then set the model back to train mode.
#
# ```python
# # turn off gradients
# with torch.no_grad():
#
#     # set model to evaluation mode
#     model.eval()
#
#     # validation pass here
#     for images, labels in testloader:
#         ...
#
# # set model back to train mode
# model.train()
# ```

# %% [markdown]
# > **Exercise:** Add dropout to your model and train it on Fashion-MNIST again. See if you can get a lower validation loss or higher accuracy.

# %%
## TODO: Define your model with dropout added

from torch import nn, optim
import torch.nn.functional as F

class Classifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 10)

        self.dropout = nn.Dropout(p = 0.3)
        
    def forward(self, x):
        # make sure input tensor is flattened
        x = x.view(x.shape[0], -1)
        
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.dropout(F.relu(self.fc2(x)))
        x = self.dropout(F.relu(self.fc3(x)))

        x = F.log_softmax(self.fc4(x), dim=1)
        
        return x

# %%
## TODO: Train your model with dropout, and monitor the training progress with the validation loss and accuracy

# GPT Experimentation
model = Classifier()
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

# Check for GPU availability
device = torch.device("cuda")
print("Using device:", device)

# Move model to GPU if available
model.to(device)

epochs = 20
steps = 0

train_losses, test_losses = [], []
for e in range(epochs):
    running_loss = 0
    accuracy = 0
    for images, labels in trainloader:

        images,labels =images.to(device),labels.to(device)
        
        optimizer.zero_grad()
        
        log_ps = model(images)
        loss = criterion(log_ps, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()

        ps = torch.exp(log_ps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

    print("Epoch: {}/{}.. ".format(e+1, epochs),
        "Training Loss: {:.3f}.. ".format(running_loss/len(trainloader)),
        "Training Accuracy: {:.3f}".format(accuracy/len(trainloader)))
# Out:
# Using device: cuda
# Epoch: 1/20..  Training Loss: 0.666..  Training Accuracy: 0.761
# Epoch: 2/20..  Training Loss: 0.532..  Training Accuracy: 0.815
# Epoch: 3/20..  Training Loss: 0.508..  Training Accuracy: 0.824
# Epoch: 4/20..  Training Loss: 0.492..  Training Accuracy: 0.831
# Epoch: 5/20..  Training Loss: 0.473..  Training Accuracy: 0.837
# Epoch: 6/20..  Training Loss: 0.466..  Training Accuracy: 0.839
# Epoch: 7/20..  Training Loss: 0.460..  Training Accuracy: 0.843
# Epoch: 8/20..  Training Loss: 0.451..  Training Accuracy: 0.845
# Epoch: 9/20..  Training Loss: 0.455..  Training Accuracy: 0.843
# Epoch: 10/20..  Training Loss: 0.443..  Training Accuracy: 0.848
# Epoch: 11/20..  Training Loss: 0.438..  Training Accuracy: 0.850
# Epoch: 12/20..  Training Loss: 0.433..  Training Accuracy: 0.849
# Epoch: 13/20..  Training Loss: 0.443..  Training Accuracy: 0.847
# Epoch: 14/20..  Training Loss: 0.433..  Training Accuracy: 0.850
# Epoch: 15/20..  Training Loss: 0.433..  Training Accuracy: 0.853
# Epoch: 16/20..  Training Loss: 0.427..  Training Accuracy: 0.854
# Epoch: 17/20..  Training Loss: 0.419..  Training Accuracy: 0.858
# Epoch: 18/20..  Training Loss: 0.423..  Training Accuracy: 0.853
# Epoch: 19/20..  Training Loss: 0.422..  Training Accuracy: 0.855
# Epoch: 20/20..  Training Loss: 0.427..  Training Accuracy: 0.853

# %% [markdown]
# ## Inference
#
# Now that the model is trained, we can use it for inference. We've done this before, but now we need to remember to set the model in inference mode with `model.eval()`. You'll also want to turn off autograd with the `torch.no_grad()` context.

# %%
# Import helper module (should be in the repo)
import helper

# Test out your network!

model.eval()

dataiter = iter(testloader)
images, labels = next(dataiter)
images,labels =images.to(device),labels.to(device)
img = images[0]
# Convert 2D image to 1D vector
img = img.view(1, 784)

# Calculate the class probabilities (softmax) for img
with torch.no_grad():
    output = model.forward(img)

ps = torch.exp(output.cpu())

# Plot the image and probabilities
helper.view_classify(img.view(1, 28, 28).cpu(), ps, version='Fashion')

# %%
# GPT Experimentation
model = Classifier()
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

# Check for GPU availability
device = torch.device("cuda")
print("Using device:", device)

# Move model to GPU if available
model.to(device)

epochs = 20
steps = 0

train_losses, test_losses = [], []
for e in range(epochs):
    running_loss = 0
    for images, labels in trainloader:

        images,labels =images.to(device),labels.to(device)
        
        optimizer.zero_grad()
        
        log_ps = model(images)
        loss = criterion(log_ps, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
    else:
        # Validation pass
        test_loss = 0
        accuracy = 0

        # Set the model to evaluation mode
        model.eval()

        with torch.no_grad():
            for images, labels in testloader:
                images, labels = images.to(device),labels.to(device)
                log_ps = model(images)
                test_loss += criterion(log_ps, labels).item()

                ps = torch.exp(log_ps)
                top_p, top_class = ps.topk(1, dim=1)
                equals = top_class == labels.view(*top_class.shape)
                accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

        # Set the model back to training mode
        model.train()

        train_losses.append(running_loss/len(trainloader))
        test_losses.append(test_loss/len(testloader))

        print("Epoch: {}/{}.. ".format(e+1, epochs),
              "Training Loss: {:.3f}.. ".format(running_loss/len(trainloader)),
              "Validation Loss: {:.3f}.. ".format(test_loss/len(testloader)),
              "Validation Accuracy: {:.3f}".format(accuracy/len(testloader)))
# Out:
# Using device: cuda
# Epoch: 1/20..  Training Loss: 0.672..  Validation Loss: 0.487..  Validation Accuracy: 0.824
# Epoch: 2/20..  Training Loss: 0.538..  Validation Loss: 0.458..  Validation Accuracy: 0.838
# Epoch: 3/20..  Training Loss: 0.512..  Validation Loss: 0.440..  Validation Accuracy: 0.842
# Epoch: 4/20..  Training Loss: 0.492..  Validation Loss: 0.452..  Validation Accuracy: 0.841
# Epoch: 5/20..  Training Loss: 0.480..  Validation Loss: 0.441..  Validation Accuracy: 0.836
# Epoch: 6/20..  Training Loss: 0.477..  Validation Loss: 0.408..  Validation Accuracy: 0.854
# Epoch: 7/20..  Training Loss: 0.471..  Validation Loss: 0.413..  Validation Accuracy: 0.851
# Epoch: 8/20..  Training Loss: 0.457..  Validation Loss: 0.424..  Validation Accuracy: 0.851
# Epoch: 9/20..  Training Loss: 0.460..  Validation Loss: 0.406..  Validation Accuracy: 0.860
# Epoch: 10/20..  Training Loss: 0.453..  Validation Loss: 0.415..  Validation Accuracy: 0.851
# Epoch: 11/20..  Training Loss: 0.454..  Validation Loss: 0.409..  Validation Accuracy: 0.849
# Epoch: 12/20..  Training Loss: 0.439..  Validation Loss: 0.404..  Validation Accuracy: 0.857
# Epoch: 13/20..  Training Loss: 0.441..  Validation Loss: 0.401..  Validation Accuracy: 0.863
# Epoch: 14/20..  Training Loss: 0.443..  Validation Loss: 0.411..  Validation Accuracy: 0.855
# Epoch: 15/20..  Training Loss: 0.436..  Validation Loss: 0.409..  Validation Accuracy: 0.854
# Epoch: 16/20..  Training Loss: 0.430..  Validation Loss: 0.404..  Validation Accuracy: 0.858
# Epoch: 17/20..  Training Loss: 0.430..  Validation Loss: 0.382..  Validation Accuracy: 0.868
# Epoch: 18/20..  Training Loss: 0.426..  Validation Loss: 0.406..  Validation Accuracy: 0.856
# Epoch: 19/20..  Training Loss: 0.428..  Validation Loss: 0.390..  Validation Accuracy: 0.867
# Epoch: 20/20..  Training Loss: 0.424..  Validation Loss: 0.412..  Validation Accuracy: 0.859

# %%
import numpy as np
import matplotlib.pyplot as plt

print(len(train_losses))
print(len(test_losses))


plt.plot(list(range(epochs)),train_losses,list(range(epochs)),test_losses)
plt.xlabel("Epochs")
plt.ylabel("Loss")

# lbl =

# plt.xticks(list(range(20)),labels = )
plt.show()
# Out:
# 20
# 20

# %% [markdown]
# ## Next Up!
#
# In the next part, I'll show you how to save your trained models. In general, you won't want to train a model every time you need it. Instead, you'll train once, save it, then load the model when you want to train more or use if for inference.
